# %%
# ============================================================
# nx47_vesu_kernel_v2.5
# ============================================================
import ctypes
import ast
import glob
import importlib
import io
import json
import os
import struct
import time
import zipfile
from dataclasses import dataclass
from hashlib import sha512
from pathlib import Path
from typing import Dict, List, Optional, Sequence, Tuple

try:
    from PIL import Image, ImageSequence
except Exception:  # pragma: no cover
    Image = None
    ImageSequence = None


class FatalPipelineError(RuntimeError):
    """Raised when strict fail-fast invariants are violated."""


@dataclass(frozen=True)
class CompatibilityLayer:
    name: str
    required_capabilities: List[str]


@dataclass(frozen=True)
class LUMVolume:
    shape: Tuple[int, int, int]
    dtype: str
    payload_sha512: str


class LumVoraxBridge:
    """Optional bridge to native LUM/VORAX C/C++ libraries via ctypes.

    Bridge is optional by design: pipeline remains fully functional in pure Python
    when no native shared library is available in Kaggle runtime.
    """

    def __init__(self) -> None:
        self.lib = None
        self.loaded_path = None

        candidates = [
            os.environ.get("LUM_VORAX_LIB_PATH", ""),
            "/kaggle/working/liblumvorax.so",
            "/kaggle/working/liblumvorax_replit.so",
            "/kaggle/working/libvorax.so",
            "/kaggle/input/lum-vorax-dependencies/liblumvorax.so",
            "/kaggle/input/lum-vorax-dependencies/libvorax.so",
            "/kaggle/input/datasets/ndarray2000/nx47-dependencies/liblumvorax_replit.so",
        ]
        for candidate in candidates:
            if candidate and os.path.exists(candidate):
                self.lib = ctypes.CDLL(candidate)
                self.loaded_path = candidate
                break

    @property
    def enabled(self) -> bool:
        return self.lib is not None


class NX47_VESU_Production:
    """NX-47 VESU production pipeline (Kaggle-ready, fail-fast, forensic).

    Key guarantees:
    - No synthetic fragment fallback.
    - Real TIFF input ingestion (2D or 3D, normalized to 3D).
    - Progressive multi-threshold 3D accumulation with target density clamping.
    - Optional `.lum` canonical intermediate serialization.
    - Optional native LUM/VORAX bridge via ctypes (non-blocking fallback).
    """

    ROADMAP_STEPS = [
        "bootstrap",
        "compatibility_check",
        "data_validation",
        "feature_extraction",
        "inference",
        "forensic_export",
        "finalize",
    ]

    LUM_MAGIC = b"LUMV1\x00\x00\x00"

    def __init__(self, input_dir=None, output_dir=None):
        self.version = "NX-47 VESU PROD V141-REAL-PY"
        self.audit_log: List[Dict] = []
        self.start_time = time.time_ns()
        env_input = os.environ.get("NX47_INPUT_DIR")
        self.input_dir = input_dir or env_input or "/kaggle/input/vesuvius-challenge-surface-detection"
        self.effective_input_root = self.input_dir
        self.discovery_attempts: List[Dict[str, object]] = []
        env_output = os.environ.get("NX47_OUTPUT_DIR")
        self.output_dir = output_dir or env_output or "/kaggle/working"
        self.processed_pixels = 0
        self.ink_detected = 0
        self.fallback_disabled = True
        self.roadmap_path = os.path.join(self.output_dir, "v141_roadmap_realtime.json")
        self.execution_log_path = os.path.join(self.output_dir, "v141_execution_logs.json")
        self.metadata_path = os.path.join(self.output_dir, "v141_execution_metadata.json")
        self.submission_zip_path = os.path.join(self.output_dir, "submission.zip")
        self.submission_parquet_path = os.path.join(self.output_dir, "submission.parquet")
        self.lum_work_dir = os.path.join(self.output_dir, "lum_cache")
        self.bridge = LumVoraxBridge()
        self.binary_mode = os.environ.get("NX47_BINARY_MODE", "0_1").strip().lower()
        if self.binary_mode not in {"0_1", "0_255"}:
            raise FatalPipelineError(f"INVALID_BINARY_MODE: {self.binary_mode}")

        self.capability_registry = {
            "preprocess_invariants": self.spatial_harmonic_filtering_simd,
            "input_format_guard": self._validate_input_structure,
            "feature_signature_v2": self._extract_fragment_signature,
            "intermediate_schema_v2": self._build_result_entry,
            "audit_hash_chain": self.log_event,
            "integrity_checks": self._integrity_digest,
            "forensic_traceability": self._export_forensic,
            "merkle_ready_events": self._audit_merkle_root,
            "realtime_roadmap": self._update_roadmap,
            "strict_train_evidence_gate": self._strict_training_evidence_gate,
            "adaptive_thresholding": self.ink_resonance_detector_v47,
            "dynamic_neuron_telemetry": self._emit_neuron_telemetry,
            "lum_encode_decode": self._roundtrip_lum,
        }

        self.compatibility_layers = [
            CompatibilityLayer("NX-1..NX-10", ["preprocess_invariants", "input_format_guard"]),
            CompatibilityLayer("NX-11..NX-20", ["feature_signature_v2", "intermediate_schema_v2"]),
            CompatibilityLayer("NX-21..NX-35", ["audit_hash_chain", "integrity_checks"]),
            CompatibilityLayer(
                "NX-36..NX-47",
                ["forensic_traceability", "merkle_ready_events", "realtime_roadmap", "dynamic_neuron_telemetry"],
            ),
            CompatibilityLayer(
                "NX-47 v115..v140",
                ["strict_train_evidence_gate", "adaptive_thresholding", "realtime_roadmap", "lum_encode_decode"],
            ),
        ]

        print(f"[{self.version}] System Initialized. Real TIFF processing + `.lum` roundtrip + fail-fast active.")

    @staticmethod
    def _is_pkg_available(package_name: str) -> bool:
        return importlib.util.find_spec(package_name) is not None

    @staticmethod
    def _matching_wheels(package_name: str, wheel_roots: Sequence[Path]) -> List[Path]:
        matches: List[Path] = []
        for root in wheel_roots:
            if not root.exists():
                continue
            matches.extend(sorted(root.glob(f"{package_name}-*.whl")))
        return matches

    def _run_pip_install(self, args: List[str], package_name: str) -> None:
        import subprocess

        timeout_s = int(os.environ.get("NX47_PIP_TIMEOUT_S", "180"))
        print(f"[{self.version}] PIP_INSTALL_START package={package_name} cmd={' ' .join(args)} timeout={timeout_s}s", flush=True)
        completed = subprocess.run(args, check=False, timeout=timeout_s)
        if completed.returncode != 0:
            raise subprocess.CalledProcessError(completed.returncode, args)
        print(f"[{self.version}] PIP_INSTALL_DONE package={package_name}", flush=True)

    def install_offline(self, package_name: str, required: bool = True) -> bool:
        import subprocess
        import sys

        if self._is_pkg_available(package_name):
            return True

        exact_wheel_dir = Path("/kaggle/input/datasets/ndarray2000/nx47-dependencies")
        fallback_wheel_dir = Path("/kaggle/input/nx47-dependencies")
        lum_wheel_dir = Path("/kaggle/input/lum-vorax-dependencies")
        lum_wheel_dir_alt = Path("/kaggle/input/lumvorax-dependencies")

        exact_wheels = {
            "imagecodecs": exact_wheel_dir / "imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl",
            "numpy": exact_wheel_dir / "numpy-2.4.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl",
            "tifffile": exact_wheel_dir / "tifffile-2026.1.28-py3-none-any.whl",
        }

        if package_name in exact_wheels and exact_wheels[package_name].exists():
            try:
                self._run_pip_install([sys.executable, "-m", "pip", "install", "--disable-pip-version-check", "--no-index", str(exact_wheels[package_name])], package_name)
                if self._is_pkg_available(package_name):
                    return True
            except subprocess.CalledProcessError:
                pass

        wheel_roots = [exact_wheel_dir, fallback_wheel_dir, lum_wheel_dir, lum_wheel_dir_alt]

        for root in wheel_roots:
            if root.exists():
                try:
                    self._run_pip_install(
                        [sys.executable, "-m", "pip", "install", "--disable-pip-version-check", "--no-index", f"--find-links={root}", package_name],
                        package_name,
                    )
                    if self._is_pkg_available(package_name):
                        return True
                except Exception:
                    continue

        if required:
            raise FatalPipelineError(
                f"OFFLINE_DEPENDENCY_MISSING: {package_name} not found in known wheel directories."
            )
        raise FatalPipelineError(
            f"OPTIONAL_DEPENDENCY_POLICY_DISABLED: {package_name} missing and optional mode is forbidden."
        )

    def bootstrap_dependencies_fail_fast(self) -> None:
        # Optional bypass for local/Replit root validation preflight.
        if os.environ.get("NX47_SKIP_OFFLINE_BOOTSTRAP", "0").strip().lower() in {"1", "true", "yes"}:
            self.log_event("BOOTSTRAP_SKIPPED", {"reason": "NX47_SKIP_OFFLINE_BOOTSTRAP"})
            return

        # Required runtime packages
        for pkg in ("numpy", "pandas", "tifffile", "pyarrow"):
            self.install_offline(pkg, required=True)

        # Strict dependency policy: imagecodecs is mandatory and must fail-fast if missing.
        self.install_offline("imagecodecs", required=True)


    def _emit_dependency_resolution_report(self) -> None:
        wheel_roots = [
            "/kaggle/input/datasets/ndarray2000/nx47-dependencies",
            "/kaggle/input/nx47-dependencies",
            "/kaggle/input/lum-vorax-dependencies",
            "/kaggle/input/lumvorax-dependencies",
        ]
        report = {
            "wheel_roots": [{"path": p, "exists": os.path.exists(p)} for p in wheel_roots],
            "packages": {pkg: self._is_pkg_available(pkg) for pkg in ("numpy", "pandas", "tifffile", "pyarrow", "imagecodecs")},
        }
        self.log_event("DEPENDENCY_RESOLUTION_REPORT", report)

    def _emit_native_bridge_status(self) -> None:
        self.log_event(
            "NATIVE_BRIDGE_STATUS",
            {
                "enabled": bool(self.bridge.enabled),
                "path": self.bridge.loaded_path,
                "lum_magic": self.LUM_MAGIC.decode("latin1", errors="ignore"),
            },
        )

    def _memory_snapshot(self, stage: str) -> None:
        try:
            import resource
            rss_kb = int(resource.getrusage(resource.RUSAGE_SELF).ru_maxrss)
        except Exception:
            rss_kb = -1
        self.log_event("MEMORY_SNAPSHOT", {"stage": stage, "rss_kb": rss_kb})

    @staticmethod
    def validate_source_indentation(source_path: Optional[str] = None) -> None:
        """Fail fast if source has indentation corruption (tabs/mixed blocks/syntax).

        Notebook-safe behavior:
        - in Kaggle/Papermill notebooks, ``__file__`` may be undefined;
        - we attempt multiple path candidates before deciding to skip the check.
        """
        import sys

        candidates: List[Path] = []
        if source_path:
            candidates.append(Path(source_path))
        else:
            g_file = globals().get("__file__")
            if isinstance(g_file, str) and g_file.strip():
                candidates.append(Path(g_file))
            argv0 = sys.argv[0] if sys.argv else ""
            if isinstance(argv0, str) and argv0.endswith(".py"):
                candidates.append(Path(argv0))
            candidates.append(Path.cwd() / "nx47_vesu_kernel_v2.4.py")

        target_path = next((c for c in candidates if c.exists() and c.is_file()), None)
        if target_path is None:
            # Notebook cell context without source file on disk.
            # We deliberately skip this guard instead of crashing the run.
            return

        content = target_path.read_text(encoding="utf-8")
        if "\t" in content:
            raise FatalPipelineError(f"SOURCE_INDENTATION_INVALID: tab characters found in {target_path}")
        try:
            ast.parse(content)
        except IndentationError as e:
            raise FatalPipelineError(f"SOURCE_INDENTATION_INVALID: {e}") from e
        except SyntaxError as e:
            raise FatalPipelineError(f"SOURCE_SYNTAX_INVALID: {e}") from e


    def log_event(self, event_type, details, severity="INFO"):
        ts = time.time_ns()
        previous_signature = self.audit_log[-1]["signature"] if self.audit_log else "GENESIS"
        log_entry = {
            "timestamp_ns": ts,
            "event": event_type,
            "severity": severity,
            "details": details,
            "previous_signature": previous_signature,
            "signature": sha512(f"{ts}{event_type}{details}{previous_signature}".encode()).hexdigest(),
        }
        self.audit_log.append(log_entry)

    def _update_roadmap(self, current_step, status="in_progress"):
        if current_step not in self.ROADMAP_STEPS:
            raise FatalPipelineError(f"Unknown roadmap step: {current_step}")
        current_idx = self.ROADMAP_STEPS.index(current_step)
        milestones = []
        for idx, step in enumerate(self.ROADMAP_STEPS):
            if idx < current_idx or (idx == current_idx and status == "done"):
                step_status = "done"
            elif idx == current_idx:
                step_status = "in_progress"
            else:
                step_status = "pending"
            milestones.append({"step": step, "status": step_status})
        roadmap = {
            "version": self.version,
            "timestamp_ns": time.time_ns(),
            "current_step": current_step,
            "status": status,
            "overall_progress_percent": round(
                ((current_idx + (1 if status == "done" else 0)) / len(self.ROADMAP_STEPS)) * 100, 2
            ),
            "milestones": milestones,
        }
        os.makedirs(self.output_dir, exist_ok=True)
        with open(self.roadmap_path, "w", encoding="utf-8") as f:
            json.dump(roadmap, f, indent=2)

    def _candidate_roots(self) -> List[Path]:
        configured = Path(self.input_dir)
        candidates = [
            configured,
            Path("/kaggle/input/vesuvius-challenge-surface-detection"),
            Path("/kaggle/input/competitions/vesuvius-challenge-surface-detection"),
            Path("/kaggle/input/vesuvius-challenge-ink-detection"),
            Path("/kaggle/input/competitions/vesuvius-challenge-ink-detection"),
        ]
        uniq: List[Path] = []
        seen = set()
        for c in candidates:
            k = str(c)
            if k not in seen:
                uniq.append(c)
                seen.add(k)
        return uniq

    def _resolve_input_root(self) -> Path:
        indicators = ("test", "test_scrolls", "test_fragments")
        for root in self._candidate_roots():
            has_indicator = any((root / name).exists() for name in indicators) or any(root.glob("**/test"))
            has_tiff = any(root.glob("**/*.tif")) or any(root.glob("**/*.tiff"))
            self.discovery_attempts.append(
                {"root": str(root), "exists": root.exists(), "has_indicator": bool(has_indicator), "has_tiff": bool(has_tiff)}
            )
            if root.exists() and (has_indicator or has_tiff):
                return root
        raise FatalPipelineError(
            f"INPUT_STRUCTURE_INVALID: no usable dataset root found. attempts={self.discovery_attempts}"
        )

    def _validate_input_structure(self):
        resolved = self._resolve_input_root()
        self.effective_input_root = str(resolved)

    def _collect_test_fragments(self) -> List[str]:
        root = Path(self.effective_input_root)
        candidates = []
        patterns = [
            str(root / "test" / "*.tif"),
            str(root / "test" / "*.tiff"),
            str(root / "test" / "**" / "*.tif"),
            str(root / "test" / "**" / "*.tiff"),
            str(root / "test_scrolls" / "**" / "*.tif"),
            str(root / "test_scrolls" / "**" / "*.tiff"),
            str(root / "test_fragments" / "**" / "*.tif"),
            str(root / "test_fragments" / "**" / "*.tiff"),
            str(root / "**" / "test" / "*.tif"),
            str(root / "**" / "test" / "*.tiff"),
            str(root / "**" / "surface_volume" / "*.tif"),
            str(root / "**" / "surface_volume" / "*.tiff"),
        ]
        for pattern in patterns:
            candidates.extend(glob.glob(pattern, recursive=True))

        uniq = sorted({str(Path(p)) for p in candidates})
        if not uniq:
            # last-resort recursive tif scan under root
            uniq = sorted({str(p) for p in root.rglob("*.tif")}) + sorted({str(p) for p in root.rglob("*.tiff")})
            uniq = sorted(set(uniq))
        if not uniq:
            raise FatalPipelineError(f"NO_TEST_FRAGMENTS_FOUND in {root}")
        return uniq

    def _validate_compatibility_chain(self):
        for layer in self.compatibility_layers:
            missing = [cap for cap in layer.required_capabilities if cap not in self.capability_registry]
            if missing:
                raise FatalPipelineError(f"COMPATIBILITY_BROKEN in {layer.name}: missing {missing}")
            self.log_event("COMPATIBILITY_LAYER_OK", {"layer": layer.name, "caps": layer.required_capabilities})

    def _strict_training_evidence_gate(self):
        expected = {
            "supervised_train": False,
            "val_f1_mean_supervised": None,
            "val_iou_mean_supervised": None,
            "native_bridge_enabled": self.bridge.enabled,
            "native_bridge_path": self.bridge.loaded_path,
        }
        self.log_event("STRICT_TRAINING_GATE", expected)

    @staticmethod
    def _normalize_volume_shape(volume: "np.ndarray") -> "np.ndarray":
        import numpy as np

        arr = np.asarray(volume)
        if arr.ndim == 2:
            return arr[np.newaxis, :, :]
        if arr.ndim == 3:
            return arr
        raise FatalPipelineError(f"UNSUPPORTED_VOLUME_DIM: expected 2D/3D, got {arr.ndim}D")

    def _read_tiff_volume(self, path: str) -> "np.ndarray":
        import numpy as np
        import tifffile

        try:
            arr = tifffile.imread(path)
        except ValueError as exc:
            if "requires the 'imagecodecs' package" in str(exc):
                raise FatalPipelineError(
                    f"DEPENDENCY_STRICT_FAILFAST: imagecodecs is required to decode TIFF LZW ({path})"
                ) from exc
            raise

        arr = self._normalize_volume_shape(arr)
        if arr.shape[1] <= 0 or arr.shape[2] <= 0:
            raise FatalPipelineError(f"INVALID_TIFF_SHAPE: {path} -> {arr.shape}")
        return arr.astype("float32", copy=False)

    def _lum_encode(self, volume: "np.ndarray") -> bytes:
        import numpy as np

        arr = self._normalize_volume_shape(volume)
        payload = np.ascontiguousarray(arr.astype(np.float32)).tobytes()
        digest = sha512(payload).digest()
        z, h, w = arr.shape
        header = struct.pack("<8sIII16s", self.LUM_MAGIC, z, h, w, digest[:16])
        return header + payload

    def _lum_decode(self, blob: bytes) -> "np.ndarray":
        import numpy as np

        header_size = struct.calcsize("<8sIII16s")
        if len(blob) < header_size:
            raise FatalPipelineError("LUM_DECODE_ERROR: blob too small")
        magic, z, h, w, digest16 = struct.unpack("<8sIII16s", blob[:header_size])
        if magic != self.LUM_MAGIC:
            raise FatalPipelineError("LUM_DECODE_ERROR: bad magic")
        payload = blob[header_size:]
        expected_bytes = int(z) * int(h) * int(w) * 4
        if len(payload) != expected_bytes:
            raise FatalPipelineError("LUM_DECODE_ERROR: payload size mismatch")
        if sha512(payload).digest()[:16] != digest16:
            raise FatalPipelineError("LUM_DECODE_ERROR: checksum mismatch")
        arr = np.frombuffer(payload, dtype=np.float32).reshape((z, h, w))
        return arr

    def _roundtrip_lum(self, volume: "np.ndarray") -> LUMVolume:
        blob = self._lum_encode(volume)
        decoded = self._lum_decode(blob)
        payload_sha = sha512(decoded.tobytes()).hexdigest()
        return LUMVolume(shape=tuple(decoded.shape), dtype=str(decoded.dtype), payload_sha512=payload_sha)

    def spatial_harmonic_filtering_simd(self, volume):
        import numpy as np

        vol = self._normalize_volume_shape(volume)
        filtered_slices = []
        for slice_data in vol:
            fft_data = np.fft.fft2(slice_data)
            mask = np.ones_like(slice_data, dtype=np.float32)
            rows, cols = slice_data.shape
            mask[rows // 4 : 3 * rows // 4, cols // 4 : 3 * cols // 4] = 0.5
            filtered_slices.append(np.abs(np.fft.ifft2(fft_data * mask)))
        return np.stack(filtered_slices, axis=0)

    @staticmethod
    def _clamp_density(mask_3d: "np.ndarray", density_target: float) -> "np.ndarray":
        import numpy as np

        total = mask_3d.size
        if total == 0:
            return mask_3d
        target_ones = int(total * density_target)
        if target_ones <= 0:
            return np.zeros_like(mask_3d, dtype=np.uint8)
        if target_ones >= total:
            return np.ones_like(mask_3d, dtype=np.uint8)

        flat = mask_3d.reshape(-1).astype(np.float32)
        if np.max(flat) <= 1.0 and np.min(flat) >= 0.0:
            scores = flat
        else:
            mn = float(np.min(flat))
            mx = float(np.max(flat))
            scores = (flat - mn) / (mx - mn + 1e-8)

        idx = np.argpartition(scores, -target_ones)[-target_ones:]
        out = np.zeros_like(scores, dtype=np.uint8)
        out[idx] = 1
        return out.reshape(mask_3d.shape)

    def ink_resonance_detector_v47(self, filtered_data):
        import numpy as np

        vol = self._normalize_volume_shape(filtered_data)
        mean = float(np.mean(vol))
        std = float(np.std(vol))
        thresholds = [mean + 0.8 * std, mean + 1.2 * std, mean + 1.6 * std]

        layer_low = (vol > thresholds[0]).astype(np.uint8)
        layer_mid = (vol > thresholds[1]).astype(np.uint8)
        layer_high = (vol > thresholds[2]).astype(np.uint8)

        # progressive accumulation with strictness weighting
        accum = (0.55 * layer_low + 0.30 * layer_mid + 0.15 * layer_high).astype(np.float32)
        binary = (accum >= 0.5).astype(np.uint8)

        # clamp to target density range to avoid extreme under/over segmentation
        density_now = float(np.mean(binary))
        target_density = min(max(density_now, 0.05), 0.12)
        return self._clamp_density(accum, target_density)

    def _extract_fragment_signature(self, fragment_id):
        return sha512(f"{fragment_id}|NX47".encode()).hexdigest()[:24]

    def _integrity_digest(self, payload):
        encoded = json.dumps(payload, sort_keys=True, default=str).encode()
        return sha512(encoded).hexdigest()

    def _build_result_entry(self, frag_id, score, density, shape):
        return {
            "id": frag_id,
            "target": float(score),
            "density": float(density),
            "shape_z": int(shape[0]),
            "shape_h": int(shape[1]),
            "shape_w": int(shape[2]),
            "feature_signature": self._extract_fragment_signature(frag_id),
        }

    def _emit_neuron_telemetry(self, filtered_data):
        import numpy as np

        vol = self._normalize_volume_shape(filtered_data)
        total = int(vol.size)
        active = int(np.count_nonzero(vol > np.mean(vol)))
        mid = int(np.count_nonzero(vol > (np.mean(vol) + 0.5 * np.std(vol))))
        end = int(np.count_nonzero(vol > (np.mean(vol) + 1.0 * np.std(vol))))
        return {
            "active_neurons_start_total": total,
            "active_neurons_mid_total": mid,
            "active_neurons_end_total": end,
            "mutation_events": 0,
            "pruning_events": 1,
        }

    def _audit_merkle_root(self):
        leaf_hashes = [entry["signature"] for entry in self.audit_log]
        if not leaf_hashes:
            return ""
        current = leaf_hashes
        while len(current) > 1:
            if len(current) % 2 == 1:
                current.append(current[-1])
            current = [sha512(f"{current[i]}{current[i + 1]}".encode()).hexdigest() for i in range(0, len(current), 2)]
        return current[0]


    def _to_binary_domain(self, mask: "np.ndarray") -> "np.ndarray":
        import numpy as np

        bin01 = (np.asarray(mask) > 0).astype(np.uint8)
        if self.binary_mode == "0_255":
            return (bin01 * 255).astype(np.uint8)
        return bin01

    def _write_submission_zip(self, masks: Dict[str, "np.ndarray"]) -> None:
        import tifffile

        os.makedirs(self.output_dir, exist_ok=True)
        with zipfile.ZipFile(self.submission_zip_path, "w", compression=zipfile.ZIP_STORED) as zf:
            for frag_id, mask in masks.items():
                arr = self._normalize_volume_shape(self._to_binary_domain(mask)).astype("uint8")
                tif_buf = io.BytesIO()
                try:
                    tifffile.imwrite(tif_buf, arr, compression="lzw")
                except Exception:
                    # imagecodecs may be missing in some Kaggle runs.
                    tifffile.imwrite(tif_buf, arr, compression=None)
                zf.writestr(f"{frag_id}.tif", tif_buf.getvalue())

    def _export_forensic(self, stats):
        os.makedirs(self.output_dir, exist_ok=True)
        with open(self.execution_log_path, "w", encoding="utf-8") as f:
            json.dump(self.audit_log, f, indent=2)

        metadata = {
            "version": self.version,
            "elapsed_total_s": round((time.time_ns() - self.start_time) / 1e9, 6),
            "integrity_digest": self._integrity_digest(stats),
            "merkle_root": self._audit_merkle_root(),
            "fallback_disabled": self.fallback_disabled,
            "native_bridge_enabled": self.bridge.enabled,
            "native_bridge_path": self.bridge.loaded_path,
            "submission_zip": self.submission_zip_path,
            "submission_parquet": self.submission_parquet_path,
            "binary_mode": self.binary_mode,
            "effective_input_root": self.effective_input_root,
            "discovery_attempts": self.discovery_attempts,
        }
        with open(self.metadata_path, "w", encoding="utf-8") as f:
            json.dump(metadata, f, indent=2)

    def process_fragments(self):
        import pandas as pd

        self._update_roadmap("bootstrap", "in_progress")
        self.log_event("PIPELINE_START", "Beginning fragment processing")
        print(f"[{self.version}] STAGE bootstrap:start", flush=True)
        self.bootstrap_dependencies_fail_fast()
        self._emit_dependency_resolution_report()
        self._emit_native_bridge_status()
        self._memory_snapshot("post_bootstrap")
        os.makedirs(self.lum_work_dir, exist_ok=True)

        self._strict_training_evidence_gate()
        self._update_roadmap("bootstrap", "done")
        print(f"[{self.version}] STAGE bootstrap:done", flush=True)

        self._update_roadmap("compatibility_check", "in_progress")
        self._validate_compatibility_chain()
        self._update_roadmap("compatibility_check", "done")
        print(f"[{self.version}] STAGE compatibility_check:done", flush=True)

        self._update_roadmap("data_validation", "in_progress")
        self._validate_input_structure()
        test_fragments = self._collect_test_fragments()
        self.log_event("TEST_FRAGMENT_DISCOVERY", {"count": len(test_fragments), "effective_root": self.effective_input_root, "attempts": self.discovery_attempts})
        self._update_roadmap("data_validation", "done")
        print(f"[{self.version}] STAGE data_validation:done fragments={len(test_fragments)}", flush=True)

        self._update_roadmap("feature_extraction", "in_progress")
        results = []
        telemetry = {
            "active_neurons_start_total": 0,
            "active_neurons_mid_total": 0,
            "active_neurons_end_total": 0,
            "mutation_events": 0,
            "pruning_events": 0,
        }
        masks_for_zip: Dict[str, "np.ndarray"] = {}

        total_frags = len(test_fragments)
        for idx, frag in enumerate(test_fragments, start=1):
            frag_id = os.path.splitext(os.path.basename(frag))[0]
            self.log_event("FRAGMENT_PROCESSING", {"fragment": frag_id, "path": frag})
            if idx == 1 or idx % 5 == 0 or idx == total_frags:
                print(f"[{self.version}] FRAGMENT_PROGRESS {idx}/{total_frags} id={frag_id}", flush=True)

            volume = self._read_tiff_volume(frag)
            lum_info = self._roundtrip_lum(volume)
            self.log_event("LUM_ROUNDTRIP_OK", {"fragment": frag_id, "shape": lum_info.shape, "dtype": lum_info.dtype})

            filtered = self.spatial_harmonic_filtering_simd(volume)
            pred = self.ink_resonance_detector_v47(filtered)

            score = float(pred.mean())
            density = float(pred.mean())
            results.append(self._build_result_entry(frag_id, score, density, pred.shape))

            masks_for_zip[frag_id] = pred
            self.processed_pixels += int(filtered.size)
            self.ink_detected += int(pred.sum())
            t = self._emit_neuron_telemetry(filtered)
            for k in telemetry:
                telemetry[k] += int(t.get(k, 0))

        self._update_roadmap("feature_extraction", "done")
        self._memory_snapshot("post_feature_extraction")
        print(f"[{self.version}] STAGE feature_extraction:done", flush=True)

        self._update_roadmap("inference", "in_progress")
        submission_df = pd.DataFrame(results)
        if submission_df.empty:
            raise FatalPipelineError("NO_RESULTS_GENERATED")
        submission_df[["id", "target"]].to_parquet(self.submission_parquet_path)
        self._write_submission_zip(masks_for_zip)
        self.log_event("SUBMISSION_GENERATED", {"shape": submission_df.shape, "zip": self.submission_zip_path})
        self._update_roadmap("inference", "done")
        print(f"[{self.version}] STAGE inference:done", flush=True)

        self._update_roadmap("forensic_export", "in_progress")
        stats = {
            "files_processed": len(results),
            "pixels_processed": self.processed_pixels,
            "ink_detected": self.ink_detected,
            "mean_density": float(submission_df["density"].mean()),
            **telemetry,
            "files_autonomous_fallback": 0,
            "lum_bridge_enabled": self.bridge.enabled,
        }
        self._export_forensic(stats)
        self._update_roadmap("forensic_export", "done")
        self._memory_snapshot("post_forensic_export")
        print(f"[{self.version}] STAGE forensic_export:done", flush=True)

        self._update_roadmap("finalize", "done")
        print(f"[{self.version}] Execution Complete.")
        return stats


if __name__ == "__main__":
    NX47_VESU_Production.validate_source_indentation()
    node = NX47_VESU_Production()
    node.process_fragments()
# Out:
# [NX-47 VESU PROD V141-REAL-PY] System Initialized. Real TIFF processing + `.lum` roundtrip + fail-fast active.
# [NX-47 VESU PROD V141-REAL-PY] STAGE bootstrap:start
# [NX-47 VESU PROD V141-REAL-PY] PIP_INSTALL_START package=imagecodecs cmd=/usr/bin/python3 -m pip install --disable-pip-version-check --no-index /kaggle/input/datasets/ndarray2000/nx47-dependencies/imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl timeout=180s
# Processing /kaggle/input/datasets/ndarray2000/nx47-dependencies/imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from imagecodecs==2026.1.14) (2.0.2)
# Installing collected packages: imagecodecs
# Successfully installed imagecodecs-2026.1.14
# [NX-47 VESU PROD V141-REAL-PY] PIP_INSTALL_DONE package=imagecodecs
# [NX-47 VESU PROD V141-REAL-PY] STAGE bootstrap:done
# [NX-47 VESU PROD V141-REAL-PY] STAGE compatibility_check:done
# [NX-47 VESU PROD V141-REAL-PY] STAGE data_validation:done fragments=1613
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1/1613 id=1407735
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 5/1613 id=2075542469
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 10/1613 id=2996066940
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 15/1613 id=3398456664
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 20/1613 id=885379642
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 25/1613 id=2075542469
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 30/1613 id=2996066940
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 35/1613 id=3398456664
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 40/1613 id=885379642
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 45/1613 id=102536988
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 50/1613 id=105068588
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 55/1613 id=1079776201
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 60/1613 id=110997297
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 65/1613 id=11460685
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 70/1613 id=11630450
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 75/1613 id=118632705
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 80/1613 id=1204899528
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 85/1613 id=1215679884
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 90/1613 id=1238390590
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 95/1613 id=1253813461
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 100/1613 id=1272760814
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 105/1613 id=1316805721
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 110/1613 id=1351645019
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 115/1613 id=1370134939
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 120/1613 id=1412233012
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 125/1613 id=1435658104
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 130/1613 id=1454104195
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 135/1613 id=1483500546
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 140/1613 id=1505792607
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 145/1613 id=1524465289
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 150/1613 id=1553955454
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 155/1613 id=1566185731
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 160/1613 id=159112826
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 165/1613 id=1613378452
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 170/1613 id=162812671
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 175/1613 id=1643996246
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 180/1613 id=1671010748
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 185/1613 id=1693721638
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 190/1613 id=1722912570
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 195/1613 id=1737469977
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 200/1613 id=176501514
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 205/1613 id=1791213794
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 210/1613 id=1798146413
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 215/1613 id=1823626595
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 220/1613 id=1845578058
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 225/1613 id=1866627733
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 230/1613 id=1882650170
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 235/1613 id=1923436243
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 240/1613 id=1961113613
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 245/1613 id=19797301
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 250/1613 id=2007080007
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 255/1613 id=2035810630
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 260/1613 id=2067397446
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 265/1613 id=2088623970
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 270/1613 id=2104413478
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 275/1613 id=2125961987
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 280/1613 id=2142002305
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 285/1613 id=2155812540
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 290/1613 id=2188050882
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 295/1613 id=2206870115
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 300/1613 id=2220787575
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 305/1613 id=2272064421
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 310/1613 id=2292614243
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 315/1613 id=2330704793
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 320/1613 id=2361792849
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 325/1613 id=2377884359
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 330/1613 id=241514276
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 335/1613 id=2445577751
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 340/1613 id=2475831799
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 345/1613 id=2502110845
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 350/1613 id=2530405250
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 355/1613 id=2550619349
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 360/1613 id=2579374491
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 365/1613 id=262156460
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 370/1613 id=263322541
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 375/1613 id=2660177791
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 380/1613 id=2689046967
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 385/1613 id=2716466411
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 390/1613 id=2736169384
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 395/1613 id=2759477755
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 400/1613 id=2773856183
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 405/1613 id=2786449252
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 410/1613 id=2813533679
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 415/1613 id=2855094384
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 420/1613 id=288548608
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 425/1613 id=2908683777
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 430/1613 id=2945808105
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 435/1613 id=29754811
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 440/1613 id=3002733017
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 445/1613 id=3020371188
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 450/1613 id=3034991642
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 455/1613 id=304383493
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 460/1613 id=3061154571
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 465/1613 id=3072203034
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 470/1613 id=3097347461
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 475/1613 id=3138051242
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 480/1613 id=3152234929
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 485/1613 id=3183278576
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 490/1613 id=3198627305
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 495/1613 id=3248922039
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 500/1613 id=327851248
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 505/1613 id=3298840559
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 510/1613 id=3324873066
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 515/1613 id=3342671660
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 520/1613 id=3355195275
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 525/1613 id=338740527
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 530/1613 id=3406558476
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 535/1613 id=3419802889
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 540/1613 id=3436915414
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 545/1613 id=3467185855
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 550/1613 id=3522504366
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 555/1613 id=3554743381
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 560/1613 id=3603241078
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 565/1613 id=3620638870
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 570/1613 id=3637340207
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 575/1613 id=3652794077
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 580/1613 id=3681179135
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 585/1613 id=370627915
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 590/1613 id=3742893488
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 595/1613 id=378779937
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 600/1613 id=3797609646
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 605/1613 id=3819086916
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 610/1613 id=3837479943
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 615/1613 id=3866421231
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 620/1613 id=3918162598
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 625/1613 id=3924902780
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 630/1613 id=3939111351
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 635/1613 id=3965555633
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 640/1613 id=3978531923
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 645/1613 id=4014453466
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 650/1613 id=4024884955
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 655/1613 id=40625686
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 660/1613 id=406944815
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 665/1613 id=4107199299
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 670/1613 id=415208576
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 675/1613 id=4183432614
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 680/1613 id=4192381697
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 685/1613 id=4208123944
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 690/1613 id=4221764104
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 695/1613 id=4239546470
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 700/1613 id=4273576431
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 705/1613 id=436578995
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 710/1613 id=456049089
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 715/1613 id=469888632
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 720/1613 id=500230427
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 725/1613 id=516292750
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 730/1613 id=535029841
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 735/1613 id=544161273
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 740/1613 id=568160669
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 745/1613 id=595274163
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 750/1613 id=602831951
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 755/1613 id=63469416
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 760/1613 id=656697281
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 765/1613 id=690562299
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 770/1613 id=702267251
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 775/1613 id=714558499
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 780/1613 id=724175864
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 785/1613 id=762867428
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 790/1613 id=785433964
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 795/1613 id=805297990
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 800/1613 id=840310891
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 805/1613 id=867889560
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 810/1613 id=8862040
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 815/1613 id=917058676
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 820/1613 id=944699214
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 825/1613 id=975031774
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 830/1613 id=1013184726
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 835/1613 id=1044587645
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 840/1613 id=1075217434
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 845/1613 id=1108059824
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 850/1613 id=114235076
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 855/1613 id=1159818141
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 860/1613 id=1182039038
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 865/1613 id=1201940326
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 870/1613 id=1210927642
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 875/1613 id=1238314834
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 880/1613 id=1242962297
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 885/1613 id=1271223370
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 890/1613 id=1311779219
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 895/1613 id=1341999317
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 900/1613 id=1369609932
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 905/1613 id=1404108352
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 910/1613 id=1430679851
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 915/1613 id=1449602646
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 920/1613 id=1480691377
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 925/1613 id=1505524936
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 930/1613 id=1522833038
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 935/1613 id=1542708535
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 940/1613 id=1565784049
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 945/1613 id=1589119778
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 950/1613 id=1612471366
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 955/1613 id=1625909146
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 960/1613 id=164224384
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 965/1613 id=1669670049
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 970/1613 id=1693625989
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 975/1613 id=1720613063
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 980/1613 id=1734818300
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 985/1613 id=1762562855
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 990/1613 id=1790856995
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 995/1613 id=1796762532
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1000/1613 id=1820528268
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1005/1613 id=1842921029
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1010/1613 id=1858247918
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1015/1613 id=1881495000
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1020/1613 id=1914571029
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1025/1613 id=1960540938
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1030/1613 id=1967300661
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1035/1613 id=2004658464
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1040/1613 id=2024572193
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1045/1613 id=206065757
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1050/1613 id=2087850246
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1055/1613 id=2101035605
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1060/1613 id=2116542410
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1065/1613 id=2137776807
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1070/1613 id=2152970898
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1075/1613 id=2178672922
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1080/1613 id=2205179329
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1085/1613 id=2220704498
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1090/1613 id=2268918028
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1095/1613 id=2290837
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1100/1613 id=2314417530
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1105/1613 id=2352678715
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1110/1613 id=2375325173
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1115/1613 id=241509106
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1120/1613 id=244496252
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1125/1613 id=2473381112
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1130/1613 id=2497392974
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1135/1613 id=2524776433
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1140/1613 id=2544642863
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1145/1613 id=2556347231
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1150/1613 id=2615287684
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1155/1613 id=2632109508
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1160/1613 id=2656396745
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1165/1613 id=2676456148
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1170/1613 id=2713673035
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1175/1613 id=2734445540
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1180/1613 id=2757775745
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1185/1613 id=2770853879
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1190/1613 id=2785199107
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1195/1613 id=2809620240
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1200/1613 id=2851151222
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1205/1613 id=2881190689
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1210/1613 id=2902582474
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1215/1613 id=294458037
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1220/1613 id=2972783115
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1225/1613 id=2988223195
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1230/1613 id=3019071518
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1235/1613 id=3031545955
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1240/1613 id=3043804417
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1245/1613 id=3060150865
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1250/1613 id=3070061281
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1255/1613 id=3090197578
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1260/1613 id=3137156884
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1265/1613 id=315189226
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1270/1613 id=3183136322
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1275/1613 id=3194326202
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1280/1613 id=324225693
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1285/1613 id=3276984492
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1290/1613 id=3294954456
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1295/1613 id=3321304167
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1300/1613 id=3340933719
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1305/1613 id=3351412255
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1310/1613 id=3376387932
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1315/1613 id=3403995981
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1320/1613 id=3414605268
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1325/1613 id=3436049398
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1330/1613 id=344456112
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1335/1613 id=3522460784
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1340/1613 id=3545147380
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1345/1613 id=3602356228
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1350/1613 id=3614895682
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1355/1613 id=3635486343
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1360/1613 id=364978558
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1365/1613 id=3676026615
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1370/1613 id=3700757712
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1375/1613 id=3732127861
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1380/1613 id=3774596591
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1385/1613 id=3794435116
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1390/1613 id=3811489418
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1395/1613 id=3834183540
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1400/1613 id=3854983004
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1405/1613 id=3904609999
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1410/1613 id=3922476405
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1415/1613 id=3931902777
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1420/1613 id=3965259126
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1425/1613 id=3977024865
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1430/1613 id=399611216
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1435/1613 id=4024699648
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1440/1613 id=4055275941
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1445/1613 id=4066091069
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1450/1613 id=4105398542
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1455/1613 id=4125736882
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1460/1613 id=4180160757
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1465/1613 id=4187712419
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1470/1613 id=4205218927
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1475/1613 id=4218389312
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1480/1613 id=4235140888
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1485/1613 id=426871543
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1490/1613 id=435122332
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1495/1613 id=45525309
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1500/1613 id=469842901
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1505/1613 id=489804959
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1510/1613 id=513390852
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1515/1613 id=53160227
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1520/1613 id=541673255
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1525/1613 id=567464717
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1530/1613 id=584514551
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1535/1613 id=60272894
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1540/1613 id=633046981
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1545/1613 id=648443467
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1550/1613 id=687559918
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1555/1613 id=702123980
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1560/1613 id=711832556
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1565/1613 id=722561671
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1570/1613 id=746664827
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1575/1613 id=777463733
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1580/1613 id=803213133
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1585/1613 id=826588329
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1590/1613 id=86701140
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1595/1613 id=885730675
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1600/1613 id=916238493
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1605/1613 id=933191725
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1610/1613 id=969293709
# [NX-47 VESU PROD V141-REAL-PY] FRAGMENT_PROGRESS 1613/1613 id=992852942
# [NX-47 VESU PROD V141-REAL-PY] STAGE feature_extraction:done
# [NX-47 VESU PROD V141-REAL-PY] STAGE inference:done
# [NX-47 VESU PROD V141-REAL-PY] STAGE forensic_export:done
# [NX-47 VESU PROD V141-REAL-PY] Execution Complete.
