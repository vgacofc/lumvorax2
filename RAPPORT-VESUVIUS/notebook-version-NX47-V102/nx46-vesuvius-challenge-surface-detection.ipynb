# %%
import gc
import importlib
import json
import math
import os
import subprocess
import sys
import time
import zipfile
from dataclasses import dataclass, field
from pathlib import Path
from typing import Dict, List, Tuple

import numpy as np

try:
    import cupy as cp
    from cupyx.scipy.ndimage import gaussian_filter as gpu_gaussian_filter
except Exception:
    cp = None
    gpu_gaussian_filter = None

from scipy.ndimage import gaussian_filter as cpu_gaussian_filter
from scipy.ndimage import sobel

import tifffile

try:
    from PIL import Image, ImageSequence
except Exception:
    Image = None
    ImageSequence = None


def install_offline(package_name: str) -> None:
    """Install a package from exact Kaggle offline dependency locations only."""
    exact_wheel_dir = Path("/kaggle/input/datasets/ndarray2000/nx47-dependencies")
    fallback_wheel_dir = Path("/kaggle/input/nx47-dependencies")

    exact_wheels = {
        "imagecodecs": exact_wheel_dir / "imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl",
        "numpy": exact_wheel_dir / "numpy-2.4.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl",
        "tifffile": exact_wheel_dir / "tifffile-2026.1.28-py3-none-any.whl",
    }

    # Avoid forcing an incompatible NumPy wheel (e.g. cp311 wheel on cp312 runtime).
    if package_name == "numpy":
        try:
            import numpy as _np  # noqa: F401
            return
        except Exception:
            pass

    if package_name in exact_wheels and exact_wheels[package_name].exists():
        try:
            subprocess.check_call([sys.executable, "-m", "pip", "install", "--no-index", str(exact_wheels[package_name])])
            return
        except subprocess.CalledProcessError:
            # Fall back to --find-links resolution for interpreter/platform compatibility.
            pass

    if exact_wheel_dir.exists():
        subprocess.check_call(
            [
                sys.executable,
                "-m",
                "pip",
                "install",
                "--no-index",
                f"--find-links={exact_wheel_dir}",
                package_name,
            ]
        )
        return

    if fallback_wheel_dir.exists():
        subprocess.check_call(
            [
                sys.executable,
                "-m",
                "pip",
                "install",
                "--no-index",
                f"--find-links={fallback_wheel_dir}",
                package_name,
            ]
        )
        return

    raise RuntimeError(
        "Offline dependency directory not found. Expected one of: "
        f"{exact_wheel_dir} or {fallback_wheel_dir}"
    )


def bootstrap_dependencies_fail_fast() -> None:
    # Respect exact offline process and ordering requested for Kaggle runtime.
    # NumPy is often already present and wheel tags may differ by Python minor version.
    install_offline("numpy")
    install_offline("imagecodecs")
    install_offline("tifffile")

    # Refresh tifffile module state after wheel installs in the same interpreter.
    global tifffile
    tifffile = importlib.reload(tifffile)


def ensure_imagecodecs() -> bool:
    """Ensure imagecodecs is available for LZW TIFF read/write."""
    try:
        import imagecodecs  # noqa: F401
        return True
    except Exception:
        pass

    try:
        install_offline("imagecodecs")
        import imagecodecs  # noqa: F401

        # tifffile may have been imported before imagecodecs installation.
        # Reload it so compression codecs are re-detected in the same process.
        global tifffile
        tifffile = importlib.reload(tifffile)
        return True
    except Exception:
        return False


def read_tiff_lzw_safe(path: Path) -> np.ndarray:
    """Read TIFF volumes with tifffile, then robustly fallback if LZW codecs still fail."""
    try:
        return tifffile.imread(path)
    except ValueError as exc:
        if "requires the 'imagecodecs' package" not in str(exc):
            raise

    # Try to install/refresh codecs, then retry tifffile once.
    ensure_imagecodecs()
    try:
        return tifffile.imread(path)
    except ValueError as exc:
        if "requires the 'imagecodecs' package" not in str(exc):
            raise

    # Final fallback: Pillow decoder path.
    if Image is None or ImageSequence is None:
        raise RuntimeError(
            "LZW TIFF read failed after imagecodecs bootstrap and Pillow fallback is unavailable."
        )

    with Image.open(path) as img:
        frames = [np.array(frame, dtype=np.float32) for frame in ImageSequence.Iterator(img)]

    if not frames:
        raise RuntimeError(f"No frames decoded from TIFF: {path}")

    return np.stack(frames, axis=0)


def write_tiff_lzw_safe(path: Path, arr: np.ndarray) -> None:
    """Write LZW TIFF using tifffile, fallback to Pillow when codecs are unavailable."""
    try:
        if ensure_imagecodecs():
            tifffile.imwrite(path, arr, compression="LZW")
            return
    except Exception:
        pass

    if Image is None:
        raise RuntimeError(
            "LZW TIFF write failed: imagecodecs unavailable and Pillow fallback unavailable."
        )

    pages = [Image.fromarray(frame.astype(np.uint8)) for frame in arr]
    if not pages:
        raise RuntimeError("Cannot write empty TIFF volume")
    pages[0].save(path, save_all=True, append_images=pages[1:], compression="tiff_lzw")


@dataclass
class PlanStep:
    name: str
    description: str
    progress: float = 0.0
    done: bool = False


@dataclass
class PlanTracker:
    output_path: Path
    steps: List[PlanStep] = field(default_factory=list)

    def add_step(self, name: str, description: str) -> None:
        self.steps.append(PlanStep(name=name, description=description))

    def update(self, name: str, progress: float, done: bool = False) -> None:
        for step in self.steps:
            if step.name == name:
                step.progress = float(np.clip(progress, 0.0, 100.0))
                step.done = done
                break
        self._write()

    def _write(self) -> None:
        payload = {
            "generated_at_ns": time.time_ns(),
            "roadmap": [
                {
                    "name": s.name,
                    "description": s.description,
                    "progress_percent": round(s.progress, 2),
                    "done": s.done,
                }
                for s in self.steps
            ],
            "overall_progress_percent": round(float(np.mean([s.progress for s in self.steps])) if self.steps else 0.0, 2),
        }
        self.output_path.write_text(json.dumps(payload, indent=2), encoding="utf-8")


class NX47V96Kernel:
    """
    V96 pipeline data-driven for Vesuvius test_images format.
    - Input format: *.tif volume files in /kaggle/input/competitions/vesuvius-challenge-surface-detection/test_images
    - Output format: submission.zip containing one LZW-compressed TIFF mask per input file with same filename.
    """

    def __init__(
        self,
        root: Path = Path("/kaggle/input/competitions/vesuvius-challenge-surface-detection"),
        output_dir: Path = Path("/kaggle/working"),
        overlay_stride: int = 8,
    ) -> None:
        self.root = root
        self.test_dir = self.root / "test_images"
        self.output_dir = output_dir
        self.tmp_dir = output_dir / "tmp_masks"
        self.overlay_dir = output_dir / "overlays"
        self.roadmap_path = output_dir / "v96_roadmap_realtime.json"
        self.submission_path = output_dir / "submission.zip"
        self.overlay_stride = max(1, int(overlay_stride))

        bootstrap_dependencies_fail_fast()
        if not ensure_imagecodecs():
            raise RuntimeError(
                "imagecodecs is mandatory at kernel startup for LZW TIFF I/O. "
                "Provide offline wheels in /kaggle/input/datasets/ndarray2000/nx47-dependencies (preferred) or /kaggle/input/nx47-dependencies."
            )

        self.tmp_dir.mkdir(parents=True, exist_ok=True)
        self.overlay_dir.mkdir(parents=True, exist_ok=True)

        self.plan = PlanTracker(output_path=self.roadmap_path)
        self.plan.add_step("discovery", "Validation des dossiers/format de competition")
        self.plan.add_step("load", "Chargement volume TIFF + normalisation")
        self.plan.add_step("features", "Extraction NX-47 / Neurones atom / NX-47 fusion")
        self.plan.add_step("segment", "Segmentation dynamique slice par slice")
        self.plan.add_step("overlay", "Generation overlay pixel/motifs + reconstruction")
        self.plan.add_step("package", "Generation submission.zip format exact Kaggle")
        self.plan._write()

        self.logs: List[Dict[str, object]] = []

    def log(self, event: str, **kwargs: object) -> None:
        record = {"ts_ns": time.time_ns(), "event": event, **kwargs}
        self.logs.append(record)
        print(json.dumps(record, ensure_ascii=False))

    @property
    def using_gpu(self) -> bool:
        return cp is not None

    def _xp(self):
        return cp if self.using_gpu else np

    def _gaussian(self, arr, sigma: float):
        if self.using_gpu:
            return gpu_gaussian_filter(arr, sigma=sigma)
        return cpu_gaussian_filter(arr, sigma=sigma)

    def discover_inputs(self) -> List[Path]:
        self.plan.update("discovery", 25.0)
        if not self.test_dir.exists():
            raise FileNotFoundError(f"Missing test_images directory: {self.test_dir}")
        files = sorted(self.test_dir.rglob("*.tif"))
        if not files:
            raise RuntimeError(f"No TIFF files found in {self.test_dir}")
        self.log("INPUT_DISCOVERED", file_count=len(files), using_gpu=self.using_gpu)
        self.plan.update("discovery", 100.0, done=True)
        return files

    def read_volume(self, path: Path) -> np.ndarray:
        self.plan.update("load", 25.0)
        vol = read_tiff_lzw_safe(path).astype(np.float32)
        if vol.ndim != 3:
            raise RuntimeError(f"Unsupported TIFF shape for {path.name}: {vol.shape}")
        vmin = float(vol.min())
        vmax = float(vol.max())
        vol = (vol - vmin) / (vmax - vmin + 1e-6)
        self.plan.update("load", 100.0, done=True)
        return vol

    def extract_features(self, vol: np.ndarray) -> Dict[str, float]:
        self.plan.update("features", 20.0)
        gx = sobel(vol, axis=2)
        gy = sobel(vol, axis=1)
        gz = sobel(vol, axis=0)

        gradient_energy = float(np.mean(np.sqrt(gx * gx + gy * gy + gz * gz)))
        intensity_std = float(np.std(vol))
        intensity_mean = float(np.mean(vol))
        p95 = float(np.percentile(vol, 95))
        p50 = float(np.percentile(vol, 50))

        hist, _ = np.histogram(vol, bins=64, range=(0.0, 1.0), density=True)
        entropy = -float(np.sum(hist * np.log(hist + 1e-8)))

        nx47_signal = 0.35 * gradient_energy + 0.30 * intensity_std + 0.20 * (p95 - p50) + 0.15 * entropy
        atom_neuron_signal = (1.0 + math.tanh((intensity_mean - 0.45) * 4.0)) * (1.0 + math.tanh((intensity_std - 0.12) * 8.0))
        fusion_score = 0.7 * math.tanh(nx47_signal * 3.0) + 0.3 * math.tanh(atom_neuron_signal)
        fusion_score = float(np.clip(fusion_score + 0.05, 0.0, 1.0))

        self.plan.update("features", 100.0, done=True)
        return {
            "gradient_energy": gradient_energy,
            "intensity_std": intensity_std,
            "intensity_mean": intensity_mean,
            "entropy": entropy,
            "nx47_signal": nx47_signal,
            "atom_neuron_signal": atom_neuron_signal,
            "fusion_score": fusion_score,
        }

    def segment_volume(self, vol: np.ndarray, fusion_score: float) -> np.ndarray:
        self.plan.update("segment", 10.0)
        xp = self._xp()
        vol_xp = xp.asarray(vol)

        sigma = float(max(0.5, np.std(vol) * 1.1 + 0.35))
        smooth = self._gaussian(vol_xp, sigma=sigma)
        resid = vol_xp - smooth

        z_count = int(vol.shape[0])
        masks = []
        for z in range(z_count):
            if z % max(1, z_count // 20) == 0:
                self.plan.update("segment", 10.0 + 80.0 * (z / max(1, z_count - 1)))

            z0, z1 = max(0, z - 1), min(z_count, z + 2)
            proj = xp.mean(resid[z0:z1], axis=0)
            local_std = float(xp.std(vol_xp[max(0, z - 2):min(z_count, z + 3)]))

            adaptive_weight = 0.12 + 0.22 * math.tanh(fusion_score * 2.2) * math.tanh(local_std * 6.0)
            proj = proj + adaptive_weight

            proj_cpu = cp.asnumpy(proj) if self.using_gpu else proj
            p_lo = float(np.percentile(proj_cpu, 84))
            p_hi = float(np.percentile(proj_cpu, 92))

            den = (p_hi - p_lo) + 1e-6
            w = xp.clip((proj - p_lo) / den, 0.0, 1.0)
            hi = proj > p_hi
            lo = proj > p_lo
            final = (w * xp.logical_and(hi, lo) + (1.0 - w) * xp.logical_or(hi, lo)) > 0.5
            masks.append(final.astype(xp.uint8) * 255)

            self.log(
                "SLICE_METRIC",
                z=z,
                fusion_score=round(fusion_score, 6),
                local_std=round(local_std, 6),
                adaptive_weight=round(adaptive_weight, 6),
                p_lo=round(p_lo, 6),
                p_hi=round(p_hi, 6),
            )

        stacked = xp.stack(masks)
        self.plan.update("segment", 100.0, done=True)
        return cp.asnumpy(stacked) if self.using_gpu else stacked

    def _save_overlay(self, file_stem: str, vol: np.ndarray, mask: np.ndarray) -> None:
        self.plan.update("overlay", 20.0)
        try:
            import matplotlib.pyplot as plt
        except Exception as exc:
            self.log("OVERLAY_SKIPPED", reason=f"matplotlib unavailable: {exc}")
            self.plan.update("overlay", 100.0, done=True)
            return

        z_count = vol.shape[0]
        for idx, z in enumerate(range(0, z_count, self.overlay_stride), start=1):
            base = vol[z]
            m = (mask[z] > 0).astype(np.uint8)

            fig, ax = plt.subplots(1, 1, figsize=(8, 8))
            ax.imshow(base, cmap="gray")
            ax.imshow(np.ma.masked_where(m == 0, m), cmap="autumn", alpha=0.45)
            ax.set_title(f"{file_stem} | slice {z} | legende: orange=motifs detectes")
            ax.axis("off")
            out_path = self.overlay_dir / f"{file_stem}_slice_{z:04d}_overlay.png"
            fig.savefig(out_path, dpi=120, bbox_inches="tight")
            plt.close(fig)

            prog = 20.0 + 70.0 * (idx / max(1, len(range(0, z_count, self.overlay_stride))))
            self.plan.update("overlay", prog)

        recon = (np.mean(mask.astype(np.float32) / 255.0, axis=0) * 255.0).astype(np.uint8)
        recon_path = self.overlay_dir / f"{file_stem}_reconstruction_total.png"
        tifffile.imwrite(self.overlay_dir / f"{file_stem}_reconstruction_total.tif", recon)

        fig, ax = plt.subplots(1, 1, figsize=(8, 8))
        ax.imshow(recon, cmap="inferno")
        ax.set_title(f"{file_stem} | reconstruction totale pixel par pixel")
        ax.axis("off")
        fig.savefig(recon_path, dpi=120, bbox_inches="tight")
        plt.close(fig)

        self.plan.update("overlay", 100.0, done=True)

    def run(self) -> Path:
        files = self.discover_inputs()

        self.plan.update("package", 10.0)
        with zipfile.ZipFile(self.submission_path, "w", zipfile.ZIP_STORED) as zf:
            for i, fpath in enumerate(files, start=1):
                self.log("FILE_START", file=fpath.name, index=i, total=len(files))
                self.plan.update("load", 0.0, done=False)
                self.plan.update("features", 0.0, done=False)
                self.plan.update("segment", 0.0, done=False)
                self.plan.update("overlay", 0.0, done=False)

                vol = self.read_volume(fpath)
                features = self.extract_features(vol)
                self.log("FEATURES", file=fpath.name, **{k: round(v, 6) for k, v in features.items()})

                mask = self.segment_volume(vol, fusion_score=features["fusion_score"])
                self._save_overlay(fpath.stem, vol, mask)

                out_mask = self.tmp_dir / fpath.name
                if not ensure_imagecodecs():
                    raise RuntimeError(
                        "imagecodecs is required to write Kaggle-compatible LZW TIFF masks. "
                        "Provide /kaggle/input/datasets/ndarray2000/nx47-dependencies or /kaggle/input/nx47-dependencies."
                    )
                write_tiff_lzw_safe(out_mask, mask)
                zf.write(out_mask, arcname=fpath.name)
                out_mask.unlink(missing_ok=True)
                gc.collect()

                self.log("FILE_DONE", file=fpath.name, slices=int(mask.shape[0]))
                self.plan.update("package", 10.0 + 85.0 * (i / len(files)))

        metadata = {
            "submission_zip": str(self.submission_path),
            "input_dir": str(self.test_dir),
            "output_masks_format": "LZW compressed TIFF, same name as input",
            "overlay_dir": str(self.overlay_dir),
            "log_count": len(self.logs),
            "gpu": self.using_gpu,
        }
        (self.output_dir / "v96_execution_metadata.json").write_text(json.dumps(metadata, indent=2), encoding="utf-8")
        (self.output_dir / "v96_execution_logs.json").write_text(json.dumps(self.logs, indent=2), encoding="utf-8")
        self.plan.update("package", 100.0, done=True)
        self.log("EXEC_COMPLETE", submission=str(self.submission_path))
        return self.submission_path


if __name__ == "__main__":
    kernel = NX47V96Kernel(
        root=Path(os.environ.get("VESUVIUS_ROOT", "/kaggle/input/competitions/vesuvius-challenge-surface-detection")),
        output_dir=Path(os.environ.get("VESUVIUS_OUTPUT", "/kaggle/working")),
        overlay_stride=int(os.environ.get("V96_OVERLAY_STRIDE", "8")),
    )
    submission = kernel.run()
    print(f"READY: {submission}")
# Out:
# Processing /kaggle/input/datasets/ndarray2000/nx47-dependencies/imagecodecs-2026.1.14-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from imagecodecs==2026.1.14) (2.0.2)
# Installing collected packages: imagecodecs
# Successfully installed imagecodecs-2026.1.14
# Processing /kaggle/input/datasets/ndarray2000/nx47-dependencies/tifffile-2026.1.28-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tifffile==2026.1.28) (2.0.2)
# Installing collected packages: tifffile
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2025.10.16
#     Uninstalling tifffile-2025.10.16:
#       Successfully uninstalled tifffile-2025.10.16
# Successfully installed tifffile-2026.1.28
# {"ts_ns": 1770855186065032331, "event": "INPUT_DISCOVERED", "file_count": 1, "using_gpu": true}
# {"ts_ns": 1770855186065692248, "event": "FILE_START", "file": "1407735.tif", "index": 1, "total": 1}
# {"ts_ns": 1770855192093389925, "event": "FEATURES", "file": "1407735.tif", "gradient_energy": 1.116988, "intensity_std": 0.110381, "intensity_mean": 0.329569, "entropy": -88.164857, "nx47_signal": -12.755178, "atom_neuron_signal": 0.509952, "fusion_score": 0.0}
# {"ts_ns": 1770855196164224913, "event": "SLICE_METRIC", "z": 0, "fusion_score": 0.0, "local_std": 0.096359, "adaptive_weight": 0.12, "p_lo": 0.123148, "p_hi": 0.125251}
# {"ts_ns": 1770855196170177165, "event": "SLICE_METRIC", "z": 1, "fusion_score": 0.0, "local_std": 0.096328, "adaptive_weight": 0.12, "p_lo": 0.122551, "p_hi": 0.124431}
# {"ts_ns": 1770855196175145489, "event": "SLICE_METRIC", "z": 2, "fusion_score": 0.0, "local_std": 0.096401, "adaptive_weight": 0.12, "p_lo": 0.122845, "p_hi": 0.124828}
# {"ts_ns": 1770855196179864581, "event": "SLICE_METRIC", "z": 3, "fusion_score": 0.0, "local_std": 0.096621, "adaptive_weight": 0.12, "p_lo": 0.122829, "p_hi": 0.124855}
# {"ts_ns": 1770855196184373540, "event": "SLICE_METRIC", "z": 4, "fusion_score": 0.0, "local_std": 0.097391, "adaptive_weight": 0.12, "p_lo": 0.12285, "p_hi": 0.124907}
# {"ts_ns": 1770855196189230318, "event": "SLICE_METRIC", "z": 5, "fusion_score": 0.0, "local_std": 0.098418, "adaptive_weight": 0.12, "p_lo": 0.122862, "p_hi": 0.124934}
# {"ts_ns": 1770855196193979085, "event": "SLICE_METRIC", "z": 6, "fusion_score": 0.0, "local_std": 0.099298, "adaptive_weight": 0.12, "p_lo": 0.122899, "p_hi": 0.125033}
# {"ts_ns": 1770855196198509051, "event": "SLICE_METRIC", "z": 7, "fusion_score": 0.0, "local_std": 0.099985, "adaptive_weight": 0.12, "p_lo": 0.122936, "p_hi": 0.125101}
# {"ts_ns": 1770855196202808107, "event": "SLICE_METRIC", "z": 8, "fusion_score": 0.0, "local_std": 0.100243, "adaptive_weight": 0.12, "p_lo": 0.122926, "p_hi": 0.125032}
# {"ts_ns": 1770855196207395644, "event": "SLICE_METRIC", "z": 9, "fusion_score": 0.0, "local_std": 0.100136, "adaptive_weight": 0.12, "p_lo": 0.122921, "p_hi": 0.125037}
# {"ts_ns": 1770855196211964610, "event": "SLICE_METRIC", "z": 10, "fusion_score": 0.0, "local_std": 0.099865, "adaptive_weight": 0.12, "p_lo": 0.122857, "p_hi": 0.124934}
# {"ts_ns": 1770855196217000374, "event": "SLICE_METRIC", "z": 11, "fusion_score": 0.0, "local_std": 0.099833, "adaptive_weight": 0.12, "p_lo": 0.122869, "p_hi": 0.124885}
# {"ts_ns": 1770855196221382749, "event": "SLICE_METRIC", "z": 12, "fusion_score": 0.0, "local_std": 0.099797, "adaptive_weight": 0.12, "p_lo": 0.122858, "p_hi": 0.124922}
# {"ts_ns": 1770855196226248897, "event": "SLICE_METRIC", "z": 13, "fusion_score": 0.0, "local_std": 0.099877, "adaptive_weight": 0.12, "p_lo": 0.122878, "p_hi": 0.124961}
# {"ts_ns": 1770855196230682087, "event": "SLICE_METRIC", "z": 14, "fusion_score": 0.0, "local_std": 0.100122, "adaptive_weight": 0.12, "p_lo": 0.12288, "p_hi": 0.12508}
# {"ts_ns": 1770855196235465517, "event": "SLICE_METRIC", "z": 15, "fusion_score": 0.0, "local_std": 0.100385, "adaptive_weight": 0.12, "p_lo": 0.122852, "p_hi": 0.124978}
# {"ts_ns": 1770855196240386560, "event": "SLICE_METRIC", "z": 16, "fusion_score": 0.0, "local_std": 0.100472, "adaptive_weight": 0.12, "p_lo": 0.122836, "p_hi": 0.124969}
# {"ts_ns": 1770855196245173899, "event": "SLICE_METRIC", "z": 17, "fusion_score": 0.0, "local_std": 0.10058, "adaptive_weight": 0.12, "p_lo": 0.122857, "p_hi": 0.124911}
# {"ts_ns": 1770855196249575644, "event": "SLICE_METRIC", "z": 18, "fusion_score": 0.0, "local_std": 0.100466, "adaptive_weight": 0.12, "p_lo": 0.122912, "p_hi": 0.12505}
# {"ts_ns": 1770855196254233115, "event": "SLICE_METRIC", "z": 19, "fusion_score": 0.0, "local_std": 0.10028, "adaptive_weight": 0.12, "p_lo": 0.122905, "p_hi": 0.125024}
# {"ts_ns": 1770855196258810152, "event": "SLICE_METRIC", "z": 20, "fusion_score": 0.0, "local_std": 0.100196, "adaptive_weight": 0.12, "p_lo": 0.122864, "p_hi": 0.124976}
# {"ts_ns": 1770855196263387967, "event": "SLICE_METRIC", "z": 21, "fusion_score": 0.0, "local_std": 0.100244, "adaptive_weight": 0.12, "p_lo": 0.122845, "p_hi": 0.124922}
# {"ts_ns": 1770855196267927912, "event": "SLICE_METRIC", "z": 22, "fusion_score": 0.0, "local_std": 0.100472, "adaptive_weight": 0.12, "p_lo": 0.122878, "p_hi": 0.12507}
# {"ts_ns": 1770855196272390012, "event": "SLICE_METRIC", "z": 23, "fusion_score": 0.0, "local_std": 0.1008, "adaptive_weight": 0.12, "p_lo": 0.122933, "p_hi": 0.125131}
# {"ts_ns": 1770855196277119158, "event": "SLICE_METRIC", "z": 24, "fusion_score": 0.0, "local_std": 0.101166, "adaptive_weight": 0.12, "p_lo": 0.122941, "p_hi": 0.125138}
# {"ts_ns": 1770855196281684562, "event": "SLICE_METRIC", "z": 25, "fusion_score": 0.0, "local_std": 0.101426, "adaptive_weight": 0.12, "p_lo": 0.122944, "p_hi": 0.125204}
# {"ts_ns": 1770855196286082134, "event": "SLICE_METRIC", "z": 26, "fusion_score": 0.0, "local_std": 0.101291, "adaptive_weight": 0.12, "p_lo": 0.122924, "p_hi": 0.125119}
# {"ts_ns": 1770855196290799188, "event": "SLICE_METRIC", "z": 27, "fusion_score": 0.0, "local_std": 0.100903, "adaptive_weight": 0.12, "p_lo": 0.122905, "p_hi": 0.125136}
# {"ts_ns": 1770855196295773632, "event": "SLICE_METRIC", "z": 28, "fusion_score": 0.0, "local_std": 0.100605, "adaptive_weight": 0.12, "p_lo": 0.12295, "p_hi": 0.125152}
# {"ts_ns": 1770855196300431657, "event": "SLICE_METRIC", "z": 29, "fusion_score": 0.0, "local_std": 0.100542, "adaptive_weight": 0.12, "p_lo": 0.122919, "p_hi": 0.125084}
# {"ts_ns": 1770855196305208852, "event": "SLICE_METRIC", "z": 30, "fusion_score": 0.0, "local_std": 0.100586, "adaptive_weight": 0.12, "p_lo": 0.122917, "p_hi": 0.125187}
# {"ts_ns": 1770855196309858882, "event": "SLICE_METRIC", "z": 31, "fusion_score": 0.0, "local_std": 0.100829, "adaptive_weight": 0.12, "p_lo": 0.12291, "p_hi": 0.125132}
# {"ts_ns": 1770855196315308474, "event": "SLICE_METRIC", "z": 32, "fusion_score": 0.0, "local_std": 0.101327, "adaptive_weight": 0.12, "p_lo": 0.122921, "p_hi": 0.12515}
# {"ts_ns": 1770855196319781586, "event": "SLICE_METRIC", "z": 33, "fusion_score": 0.0, "local_std": 0.101887, "adaptive_weight": 0.12, "p_lo": 0.122943, "p_hi": 0.125171}
# {"ts_ns": 1770855196324574660, "event": "SLICE_METRIC", "z": 34, "fusion_score": 0.0, "local_std": 0.102309, "adaptive_weight": 0.12, "p_lo": 0.122936, "p_hi": 0.125153}
# {"ts_ns": 1770855196329244444, "event": "SLICE_METRIC", "z": 35, "fusion_score": 0.0, "local_std": 0.102389, "adaptive_weight": 0.12, "p_lo": 0.122908, "p_hi": 0.125157}
# {"ts_ns": 1770855196334271485, "event": "SLICE_METRIC", "z": 36, "fusion_score": 0.0, "local_std": 0.102419, "adaptive_weight": 0.12, "p_lo": 0.122973, "p_hi": 0.125286}
# {"ts_ns": 1770855196339450307, "event": "SLICE_METRIC", "z": 37, "fusion_score": 0.0, "local_std": 0.102199, "adaptive_weight": 0.12, "p_lo": 0.122936, "p_hi": 0.125299}
# {"ts_ns": 1770855196344169878, "event": "SLICE_METRIC", "z": 38, "fusion_score": 0.0, "local_std": 0.101819, "adaptive_weight": 0.12, "p_lo": 0.122955, "p_hi": 0.125262}
# {"ts_ns": 1770855196349136403, "event": "SLICE_METRIC", "z": 39, "fusion_score": 0.0, "local_std": 0.101306, "adaptive_weight": 0.12, "p_lo": 0.122941, "p_hi": 0.125208}
# {"ts_ns": 1770855196354195621, "event": "SLICE_METRIC", "z": 40, "fusion_score": 0.0, "local_std": 0.101269, "adaptive_weight": 0.12, "p_lo": 0.122915, "p_hi": 0.125142}
# {"ts_ns": 1770855196358738848, "event": "SLICE_METRIC", "z": 41, "fusion_score": 0.0, "local_std": 0.10125, "adaptive_weight": 0.12, "p_lo": 0.122943, "p_hi": 0.125165}
# {"ts_ns": 1770855196363076495, "event": "SLICE_METRIC", "z": 42, "fusion_score": 0.0, "local_std": 0.101233, "adaptive_weight": 0.12, "p_lo": 0.122928, "p_hi": 0.12522}
# {"ts_ns": 1770855196368463313, "event": "SLICE_METRIC", "z": 43, "fusion_score": 0.0, "local_std": 0.101272, "adaptive_weight": 0.12, "p_lo": 0.122959, "p_hi": 0.125193}
# {"ts_ns": 1770855196373827927, "event": "SLICE_METRIC", "z": 44, "fusion_score": 0.0, "local_std": 0.101158, "adaptive_weight": 0.12, "p_lo": 0.122917, "p_hi": 0.125163}
# {"ts_ns": 1770855196378593081, "event": "SLICE_METRIC", "z": 45, "fusion_score": 0.0, "local_std": 0.100588, "adaptive_weight": 0.12, "p_lo": 0.122916, "p_hi": 0.125101}
# {"ts_ns": 1770855196383354964, "event": "SLICE_METRIC", "z": 46, "fusion_score": 0.0, "local_std": 0.100184, "adaptive_weight": 0.12, "p_lo": 0.122912, "p_hi": 0.125061}
# {"ts_ns": 1770855196387607183, "event": "SLICE_METRIC", "z": 47, "fusion_score": 0.0, "local_std": 0.09988, "adaptive_weight": 0.12, "p_lo": 0.122905, "p_hi": 0.12513}
# {"ts_ns": 1770855196393172195, "event": "SLICE_METRIC", "z": 48, "fusion_score": 0.0, "local_std": 0.099537, "adaptive_weight": 0.12, "p_lo": 0.122936, "p_hi": 0.125126}
# {"ts_ns": 1770855196397915655, "event": "SLICE_METRIC", "z": 49, "fusion_score": 0.0, "local_std": 0.099597, "adaptive_weight": 0.12, "p_lo": 0.122956, "p_hi": 0.125103}
# {"ts_ns": 1770855196402692738, "event": "SLICE_METRIC", "z": 50, "fusion_score": 0.0, "local_std": 0.100042, "adaptive_weight": 0.12, "p_lo": 0.122963, "p_hi": 0.125089}
# {"ts_ns": 1770855196407479873, "event": "SLICE_METRIC", "z": 51, "fusion_score": 0.0, "local_std": 0.1006, "adaptive_weight": 0.12, "p_lo": 0.122919, "p_hi": 0.125114}
# {"ts_ns": 1770855196412250677, "event": "SLICE_METRIC", "z": 52, "fusion_score": 0.0, "local_std": 0.100968, "adaptive_weight": 0.12, "p_lo": 0.122942, "p_hi": 0.125347}
# {"ts_ns": 1770855196417099368, "event": "SLICE_METRIC", "z": 53, "fusion_score": 0.0, "local_std": 0.10121, "adaptive_weight": 0.12, "p_lo": 0.122965, "p_hi": 0.125271}
# {"ts_ns": 1770855196421500860, "event": "SLICE_METRIC", "z": 54, "fusion_score": 0.0, "local_std": 0.101232, "adaptive_weight": 0.12, "p_lo": 0.122985, "p_hi": 0.125235}
# {"ts_ns": 1770855196426167717, "event": "SLICE_METRIC", "z": 55, "fusion_score": 0.0, "local_std": 0.101159, "adaptive_weight": 0.12, "p_lo": 0.122941, "p_hi": 0.125072}
# {"ts_ns": 1770855196430512311, "event": "SLICE_METRIC", "z": 56, "fusion_score": 0.0, "local_std": 0.101033, "adaptive_weight": 0.12, "p_lo": 0.122897, "p_hi": 0.125051}
# {"ts_ns": 1770855196435670834, "event": "SLICE_METRIC", "z": 57, "fusion_score": 0.0, "local_std": 0.101297, "adaptive_weight": 0.12, "p_lo": 0.122944, "p_hi": 0.125132}
# {"ts_ns": 1770855196440318970, "event": "SLICE_METRIC", "z": 58, "fusion_score": 0.0, "local_std": 0.101776, "adaptive_weight": 0.12, "p_lo": 0.122965, "p_hi": 0.125197}
# {"ts_ns": 1770855196445199853, "event": "SLICE_METRIC", "z": 59, "fusion_score": 0.0, "local_std": 0.102149, "adaptive_weight": 0.12, "p_lo": 0.123008, "p_hi": 0.125345}
# {"ts_ns": 1770855196449461479, "event": "SLICE_METRIC", "z": 60, "fusion_score": 0.0, "local_std": 0.102385, "adaptive_weight": 0.12, "p_lo": 0.122979, "p_hi": 0.125324}
# {"ts_ns": 1770855196454407518, "event": "SLICE_METRIC", "z": 61, "fusion_score": 0.0, "local_std": 0.102439, "adaptive_weight": 0.12, "p_lo": 0.123007, "p_hi": 0.125377}
# {"ts_ns": 1770855196459058263, "event": "SLICE_METRIC", "z": 62, "fusion_score": 0.0, "local_std": 0.102564, "adaptive_weight": 0.12, "p_lo": 0.12299, "p_hi": 0.125223}
# {"ts_ns": 1770855196463841574, "event": "SLICE_METRIC", "z": 63, "fusion_score": 0.0, "local_std": 0.103126, "adaptive_weight": 0.12, "p_lo": 0.122974, "p_hi": 0.12527}
# {"ts_ns": 1770855196469191667, "event": "SLICE_METRIC", "z": 64, "fusion_score": 0.0, "local_std": 0.103837, "adaptive_weight": 0.12, "p_lo": 0.123014, "p_hi": 0.12536}
# {"ts_ns": 1770855196474239307, "event": "SLICE_METRIC", "z": 65, "fusion_score": 0.0, "local_std": 0.104697, "adaptive_weight": 0.12, "p_lo": 0.123092, "p_hi": 0.125538}
# {"ts_ns": 1770855196479174683, "event": "SLICE_METRIC", "z": 66, "fusion_score": 0.0, "local_std": 0.105551, "adaptive_weight": 0.12, "p_lo": 0.123073, "p_hi": 0.125668}
# {"ts_ns": 1770855196483624689, "event": "SLICE_METRIC", "z": 67, "fusion_score": 0.0, "local_std": 0.106274, "adaptive_weight": 0.12, "p_lo": 0.123018, "p_hi": 0.125579}
# {"ts_ns": 1770855196488302973, "event": "SLICE_METRIC", "z": 68, "fusion_score": 0.0, "local_std": 0.106698, "adaptive_weight": 0.12, "p_lo": 0.123025, "p_hi": 0.12559}
# {"ts_ns": 1770855196493294952, "event": "SLICE_METRIC", "z": 69, "fusion_score": 0.0, "local_std": 0.107119, "adaptive_weight": 0.12, "p_lo": 0.123046, "p_hi": 0.125619}
# {"ts_ns": 1770855196498112965, "event": "SLICE_METRIC", "z": 70, "fusion_score": 0.0, "local_std": 0.107035, "adaptive_weight": 0.12, "p_lo": 0.123097, "p_hi": 0.125862}
# {"ts_ns": 1770855196502718895, "event": "SLICE_METRIC", "z": 71, "fusion_score": 0.0, "local_std": 0.107142, "adaptive_weight": 0.12, "p_lo": 0.123079, "p_hi": 0.125775}
# {"ts_ns": 1770855196507464967, "event": "SLICE_METRIC", "z": 72, "fusion_score": 0.0, "local_std": 0.107675, "adaptive_weight": 0.12, "p_lo": 0.123023, "p_hi": 0.125717}
# {"ts_ns": 1770855196512252366, "event": "SLICE_METRIC", "z": 73, "fusion_score": 0.0, "local_std": 0.108339, "adaptive_weight": 0.12, "p_lo": 0.123012, "p_hi": 0.125727}
# {"ts_ns": 1770855196517221194, "event": "SLICE_METRIC", "z": 74, "fusion_score": 0.0, "local_std": 0.108594, "adaptive_weight": 0.12, "p_lo": 0.12311, "p_hi": 0.126087}
# {"ts_ns": 1770855196522256674, "event": "SLICE_METRIC", "z": 75, "fusion_score": 0.0, "local_std": 0.108723, "adaptive_weight": 0.12, "p_lo": 0.123165, "p_hi": 0.126135}
# {"ts_ns": 1770855196526975700, "event": "SLICE_METRIC", "z": 76, "fusion_score": 0.0, "local_std": 0.108681, "adaptive_weight": 0.12, "p_lo": 0.123146, "p_hi": 0.12598}
# {"ts_ns": 1770855196532105287, "event": "SLICE_METRIC", "z": 77, "fusion_score": 0.0, "local_std": 0.108177, "adaptive_weight": 0.12, "p_lo": 0.123093, "p_hi": 0.125768}
# {"ts_ns": 1770855196536957507, "event": "SLICE_METRIC", "z": 78, "fusion_score": 0.0, "local_std": 0.107275, "adaptive_weight": 0.12, "p_lo": 0.122993, "p_hi": 0.125758}
# {"ts_ns": 1770855196542023308, "event": "SLICE_METRIC", "z": 79, "fusion_score": 0.0, "local_std": 0.106504, "adaptive_weight": 0.12, "p_lo": 0.123033, "p_hi": 0.125769}
# {"ts_ns": 1770855196547419479, "event": "SLICE_METRIC", "z": 80, "fusion_score": 0.0, "local_std": 0.106104, "adaptive_weight": 0.12, "p_lo": 0.123019, "p_hi": 0.125801}
# {"ts_ns": 1770855196552300737, "event": "SLICE_METRIC", "z": 81, "fusion_score": 0.0, "local_std": 0.105646, "adaptive_weight": 0.12, "p_lo": 0.123016, "p_hi": 0.125769}
# {"ts_ns": 1770855196557087811, "event": "SLICE_METRIC", "z": 82, "fusion_score": 0.0, "local_std": 0.104972, "adaptive_weight": 0.12, "p_lo": 0.123004, "p_hi": 0.12562}
# {"ts_ns": 1770855196561984059, "event": "SLICE_METRIC", "z": 83, "fusion_score": 0.0, "local_std": 0.104361, "adaptive_weight": 0.12, "p_lo": 0.122979, "p_hi": 0.125594}
# {"ts_ns": 1770855196566781730, "event": "SLICE_METRIC", "z": 84, "fusion_score": 0.0, "local_std": 0.104004, "adaptive_weight": 0.12, "p_lo": 0.122966, "p_hi": 0.12556}
# {"ts_ns": 1770855196573141393, "event": "SLICE_METRIC", "z": 85, "fusion_score": 0.0, "local_std": 0.103806, "adaptive_weight": 0.12, "p_lo": 0.123048, "p_hi": 0.125545}
# {"ts_ns": 1770855196578807758, "event": "SLICE_METRIC", "z": 86, "fusion_score": 0.0, "local_std": 0.103658, "adaptive_weight": 0.12, "p_lo": 0.123036, "p_hi": 0.12562}
# {"ts_ns": 1770855196583551898, "event": "SLICE_METRIC", "z": 87, "fusion_score": 0.0, "local_std": 0.103773, "adaptive_weight": 0.12, "p_lo": 0.12293, "p_hi": 0.125466}
# {"ts_ns": 1770855196588400540, "event": "SLICE_METRIC", "z": 88, "fusion_score": 0.0, "local_std": 0.104117, "adaptive_weight": 0.12, "p_lo": 0.12296, "p_hi": 0.125436}
# {"ts_ns": 1770855196593216855, "event": "SLICE_METRIC", "z": 89, "fusion_score": 0.0, "local_std": 0.104377, "adaptive_weight": 0.12, "p_lo": 0.122971, "p_hi": 0.125512}
# {"ts_ns": 1770855196598105233, "event": "SLICE_METRIC", "z": 90, "fusion_score": 0.0, "local_std": 0.104357, "adaptive_weight": 0.12, "p_lo": 0.122973, "p_hi": 0.125575}
# {"ts_ns": 1770855196603219083, "event": "SLICE_METRIC", "z": 91, "fusion_score": 0.0, "local_std": 0.104374, "adaptive_weight": 0.12, "p_lo": 0.122983, "p_hi": 0.125637}
# {"ts_ns": 1770855196609141589, "event": "SLICE_METRIC", "z": 92, "fusion_score": 0.0, "local_std": 0.104453, "adaptive_weight": 0.12, "p_lo": 0.122964, "p_hi": 0.125497}
# {"ts_ns": 1770855196614323154, "event": "SLICE_METRIC", "z": 93, "fusion_score": 0.0, "local_std": 0.104248, "adaptive_weight": 0.12, "p_lo": 0.122981, "p_hi": 0.125552}
# {"ts_ns": 1770855196619324975, "event": "SLICE_METRIC", "z": 94, "fusion_score": 0.0, "local_std": 0.10411, "adaptive_weight": 0.12, "p_lo": 0.123009, "p_hi": 0.125583}
# {"ts_ns": 1770855196624061128, "event": "SLICE_METRIC", "z": 95, "fusion_score": 0.0, "local_std": 0.104365, "adaptive_weight": 0.12, "p_lo": 0.122941, "p_hi": 0.125644}
# {"ts_ns": 1770855196629410396, "event": "SLICE_METRIC", "z": 96, "fusion_score": 0.0, "local_std": 0.104601, "adaptive_weight": 0.12, "p_lo": 0.122945, "p_hi": 0.125523}
# {"ts_ns": 1770855196634454918, "event": "SLICE_METRIC", "z": 97, "fusion_score": 0.0, "local_std": 0.104609, "adaptive_weight": 0.12, "p_lo": 0.122996, "p_hi": 0.125633}
# {"ts_ns": 1770855196639334230, "event": "SLICE_METRIC", "z": 98, "fusion_score": 0.0, "local_std": 0.104608, "adaptive_weight": 0.12, "p_lo": 0.122986, "p_hi": 0.125609}
# {"ts_ns": 1770855196643834717, "event": "SLICE_METRIC", "z": 99, "fusion_score": 0.0, "local_std": 0.104775, "adaptive_weight": 0.12, "p_lo": 0.122964, "p_hi": 0.125556}
# {"ts_ns": 1770855196648655652, "event": "SLICE_METRIC", "z": 100, "fusion_score": 0.0, "local_std": 0.105102, "adaptive_weight": 0.12, "p_lo": 0.122895, "p_hi": 0.125414}
# {"ts_ns": 1770855196653661127, "event": "SLICE_METRIC", "z": 101, "fusion_score": 0.0, "local_std": 0.105683, "adaptive_weight": 0.12, "p_lo": 0.122906, "p_hi": 0.125467}
# {"ts_ns": 1770855196658235840, "event": "SLICE_METRIC", "z": 102, "fusion_score": 0.0, "local_std": 0.106263, "adaptive_weight": 0.12, "p_lo": 0.122955, "p_hi": 0.125633}
# {"ts_ns": 1770855196662752119, "event": "SLICE_METRIC", "z": 103, "fusion_score": 0.0, "local_std": 0.106954, "adaptive_weight": 0.12, "p_lo": 0.122961, "p_hi": 0.125697}
# {"ts_ns": 1770855196667817037, "event": "SLICE_METRIC", "z": 104, "fusion_score": 0.0, "local_std": 0.107536, "adaptive_weight": 0.12, "p_lo": 0.122919, "p_hi": 0.125575}
# {"ts_ns": 1770855196672844585, "event": "SLICE_METRIC", "z": 105, "fusion_score": 0.0, "local_std": 0.107695, "adaptive_weight": 0.12, "p_lo": 0.122952, "p_hi": 0.125502}
# {"ts_ns": 1770855196677653344, "event": "SLICE_METRIC", "z": 106, "fusion_score": 0.0, "local_std": 0.10747, "adaptive_weight": 0.12, "p_lo": 0.12298, "p_hi": 0.12558}
# {"ts_ns": 1770855196682384639, "event": "SLICE_METRIC", "z": 107, "fusion_score": 0.0, "local_std": 0.10708, "adaptive_weight": 0.12, "p_lo": 0.122946, "p_hi": 0.125486}
# {"ts_ns": 1770855196686967728, "event": "SLICE_METRIC", "z": 108, "fusion_score": 0.0, "local_std": 0.106542, "adaptive_weight": 0.12, "p_lo": 0.122922, "p_hi": 0.125446}
# {"ts_ns": 1770855196692169959, "event": "SLICE_METRIC", "z": 109, "fusion_score": 0.0, "local_std": 0.105749, "adaptive_weight": 0.12, "p_lo": 0.122954, "p_hi": 0.125493}
# {"ts_ns": 1770855196697024584, "event": "SLICE_METRIC", "z": 110, "fusion_score": 0.0, "local_std": 0.104944, "adaptive_weight": 0.12, "p_lo": 0.122851, "p_hi": 0.125412}
# {"ts_ns": 1770855196701837974, "event": "SLICE_METRIC", "z": 111, "fusion_score": 0.0, "local_std": 0.104645, "adaptive_weight": 0.12, "p_lo": 0.122873, "p_hi": 0.125284}
# {"ts_ns": 1770855196707239167, "event": "SLICE_METRIC", "z": 112, "fusion_score": 0.0, "local_std": 0.104299, "adaptive_weight": 0.12, "p_lo": 0.122832, "p_hi": 0.125419}
# {"ts_ns": 1770855196712292829, "event": "SLICE_METRIC", "z": 113, "fusion_score": 0.0, "local_std": 0.103823, "adaptive_weight": 0.12, "p_lo": 0.12294, "p_hi": 0.125415}
# {"ts_ns": 1770855196717181787, "event": "SLICE_METRIC", "z": 114, "fusion_score": 0.0, "local_std": 0.103421, "adaptive_weight": 0.12, "p_lo": 0.122875, "p_hi": 0.125414}
# {"ts_ns": 1770855196722339696, "event": "SLICE_METRIC", "z": 115, "fusion_score": 0.0, "local_std": 0.103231, "adaptive_weight": 0.12, "p_lo": 0.122957, "p_hi": 0.12517}
# {"ts_ns": 1770855196727281884, "event": "SLICE_METRIC", "z": 116, "fusion_score": 0.0, "local_std": 0.102587, "adaptive_weight": 0.12, "p_lo": 0.122835, "p_hi": 0.125086}
# {"ts_ns": 1770855196732643250, "event": "SLICE_METRIC", "z": 117, "fusion_score": 0.0, "local_std": 0.101857, "adaptive_weight": 0.12, "p_lo": 0.122792, "p_hi": 0.125152}
# {"ts_ns": 1770855196737146393, "event": "SLICE_METRIC", "z": 118, "fusion_score": 0.0, "local_std": 0.101402, "adaptive_weight": 0.12, "p_lo": 0.122817, "p_hi": 0.125068}
# {"ts_ns": 1770855196741878761, "event": "SLICE_METRIC", "z": 119, "fusion_score": 0.0, "local_std": 0.10097, "adaptive_weight": 0.12, "p_lo": 0.122847, "p_hi": 0.125168}
# {"ts_ns": 1770855196746580454, "event": "SLICE_METRIC", "z": 120, "fusion_score": 0.0, "local_std": 0.100494, "adaptive_weight": 0.12, "p_lo": 0.122864, "p_hi": 0.125051}
# {"ts_ns": 1770855196751359413, "event": "SLICE_METRIC", "z": 121, "fusion_score": 0.0, "local_std": 0.100067, "adaptive_weight": 0.12, "p_lo": 0.122779, "p_hi": 0.125059}
# {"ts_ns": 1770855196756319322, "event": "SLICE_METRIC", "z": 122, "fusion_score": 0.0, "local_std": 0.099882, "adaptive_weight": 0.12, "p_lo": 0.122793, "p_hi": 0.125027}
# {"ts_ns": 1770855196761239581, "event": "SLICE_METRIC", "z": 123, "fusion_score": 0.0, "local_std": 0.099794, "adaptive_weight": 0.12, "p_lo": 0.122816, "p_hi": 0.125038}
# {"ts_ns": 1770855196765869538, "event": "SLICE_METRIC", "z": 124, "fusion_score": 0.0, "local_std": 0.099719, "adaptive_weight": 0.12, "p_lo": 0.12281, "p_hi": 0.12506}
# {"ts_ns": 1770855196771008018, "event": "SLICE_METRIC", "z": 125, "fusion_score": 0.0, "local_std": 0.09944, "adaptive_weight": 0.12, "p_lo": 0.122812, "p_hi": 0.125051}
# {"ts_ns": 1770855196776086445, "event": "SLICE_METRIC", "z": 126, "fusion_score": 0.0, "local_std": 0.099016, "adaptive_weight": 0.12, "p_lo": 0.12281, "p_hi": 0.125196}
# {"ts_ns": 1770855196781582456, "event": "SLICE_METRIC", "z": 127, "fusion_score": 0.0, "local_std": 0.098698, "adaptive_weight": 0.12, "p_lo": 0.122813, "p_hi": 0.125099}
# {"ts_ns": 1770855196786604101, "event": "SLICE_METRIC", "z": 128, "fusion_score": 0.0, "local_std": 0.098476, "adaptive_weight": 0.12, "p_lo": 0.122785, "p_hi": 0.125005}
# {"ts_ns": 1770855196791341187, "event": "SLICE_METRIC", "z": 129, "fusion_score": 0.0, "local_std": 0.098441, "adaptive_weight": 0.12, "p_lo": 0.122821, "p_hi": 0.124971}
# {"ts_ns": 1770855196796457543, "event": "SLICE_METRIC", "z": 130, "fusion_score": 0.0, "local_std": 0.098347, "adaptive_weight": 0.12, "p_lo": 0.122785, "p_hi": 0.124988}
# {"ts_ns": 1770855196801133470, "event": "SLICE_METRIC", "z": 131, "fusion_score": 0.0, "local_std": 0.098291, "adaptive_weight": 0.12, "p_lo": 0.122785, "p_hi": 0.125054}
# {"ts_ns": 1770855196805953470, "event": "SLICE_METRIC", "z": 132, "fusion_score": 0.0, "local_std": 0.098379, "adaptive_weight": 0.12, "p_lo": 0.122788, "p_hi": 0.125011}
# {"ts_ns": 1770855196810603110, "event": "SLICE_METRIC", "z": 133, "fusion_score": 0.0, "local_std": 0.098486, "adaptive_weight": 0.12, "p_lo": 0.122754, "p_hi": 0.124954}
# {"ts_ns": 1770855196815368624, "event": "SLICE_METRIC", "z": 134, "fusion_score": 0.0, "local_std": 0.098572, "adaptive_weight": 0.12, "p_lo": 0.122763, "p_hi": 0.124913}
# {"ts_ns": 1770855196819819964, "event": "SLICE_METRIC", "z": 135, "fusion_score": 0.0, "local_std": 0.098657, "adaptive_weight": 0.12, "p_lo": 0.122766, "p_hi": 0.124975}
# {"ts_ns": 1770855196824269898, "event": "SLICE_METRIC", "z": 136, "fusion_score": 0.0, "local_std": 0.098858, "adaptive_weight": 0.12, "p_lo": 0.122746, "p_hi": 0.124973}
# {"ts_ns": 1770855196829408265, "event": "SLICE_METRIC", "z": 137, "fusion_score": 0.0, "local_std": 0.099024, "adaptive_weight": 0.12, "p_lo": 0.122739, "p_hi": 0.124969}
# {"ts_ns": 1770855196834480857, "event": "SLICE_METRIC", "z": 138, "fusion_score": 0.0, "local_std": 0.099275, "adaptive_weight": 0.12, "p_lo": 0.122743, "p_hi": 0.124927}
# {"ts_ns": 1770855196839011736, "event": "SLICE_METRIC", "z": 139, "fusion_score": 0.0, "local_std": 0.099449, "adaptive_weight": 0.12, "p_lo": 0.122727, "p_hi": 0.124902}
# {"ts_ns": 1770855196843532297, "event": "SLICE_METRIC", "z": 140, "fusion_score": 0.0, "local_std": 0.099854, "adaptive_weight": 0.12, "p_lo": 0.122717, "p_hi": 0.124939}
# {"ts_ns": 1770855196847992871, "event": "SLICE_METRIC", "z": 141, "fusion_score": 0.0, "local_std": 0.100167, "adaptive_weight": 0.12, "p_lo": 0.122739, "p_hi": 0.12502}
# {"ts_ns": 1770855196853130424, "event": "SLICE_METRIC", "z": 142, "fusion_score": 0.0, "local_std": 0.100555, "adaptive_weight": 0.12, "p_lo": 0.122731, "p_hi": 0.124928}
# {"ts_ns": 1770855196857942418, "event": "SLICE_METRIC", "z": 143, "fusion_score": 0.0, "local_std": 0.10048, "adaptive_weight": 0.12, "p_lo": 0.122763, "p_hi": 0.125}
# {"ts_ns": 1770855196863351979, "event": "SLICE_METRIC", "z": 144, "fusion_score": 0.0, "local_std": 0.100275, "adaptive_weight": 0.12, "p_lo": 0.122741, "p_hi": 0.125097}
# {"ts_ns": 1770855196868265070, "event": "SLICE_METRIC", "z": 145, "fusion_score": 0.0, "local_std": 0.100362, "adaptive_weight": 0.12, "p_lo": 0.122724, "p_hi": 0.125048}
# {"ts_ns": 1770855196873540388, "event": "SLICE_METRIC", "z": 146, "fusion_score": 0.0, "local_std": 0.100807, "adaptive_weight": 0.12, "p_lo": 0.122752, "p_hi": 0.125081}
# {"ts_ns": 1770855196878828825, "event": "SLICE_METRIC", "z": 147, "fusion_score": 0.0, "local_std": 0.101232, "adaptive_weight": 0.12, "p_lo": 0.122755, "p_hi": 0.125111}
# {"ts_ns": 1770855196884307356, "event": "SLICE_METRIC", "z": 148, "fusion_score": 0.0, "local_std": 0.101935, "adaptive_weight": 0.12, "p_lo": 0.122801, "p_hi": 0.125441}
# {"ts_ns": 1770855196889733900, "event": "SLICE_METRIC", "z": 149, "fusion_score": 0.0, "local_std": 0.102762, "adaptive_weight": 0.12, "p_lo": 0.122852, "p_hi": 0.125492}
# {"ts_ns": 1770855196895257390, "event": "SLICE_METRIC", "z": 150, "fusion_score": 0.0, "local_std": 0.103437, "adaptive_weight": 0.12, "p_lo": 0.122861, "p_hi": 0.125731}
# {"ts_ns": 1770855196900330794, "event": "SLICE_METRIC", "z": 151, "fusion_score": 0.0, "local_std": 0.104262, "adaptive_weight": 0.12, "p_lo": 0.122905, "p_hi": 0.125556}
# {"ts_ns": 1770855196904716436, "event": "SLICE_METRIC", "z": 152, "fusion_score": 0.0, "local_std": 0.105227, "adaptive_weight": 0.12, "p_lo": 0.122888, "p_hi": 0.125648}
# {"ts_ns": 1770855196909390730, "event": "SLICE_METRIC", "z": 153, "fusion_score": 0.0, "local_std": 0.105977, "adaptive_weight": 0.12, "p_lo": 0.122926, "p_hi": 0.125841}
# {"ts_ns": 1770855196914335093, "event": "SLICE_METRIC", "z": 154, "fusion_score": 0.0, "local_std": 0.107142, "adaptive_weight": 0.12, "p_lo": 0.122971, "p_hi": 0.12594}
# {"ts_ns": 1770855196919112845, "event": "SLICE_METRIC", "z": 155, "fusion_score": 0.0, "local_std": 0.108595, "adaptive_weight": 0.12, "p_lo": 0.123028, "p_hi": 0.126117}
# {"ts_ns": 1770855196923649692, "event": "SLICE_METRIC", "z": 156, "fusion_score": 0.0, "local_std": 0.10995, "adaptive_weight": 0.12, "p_lo": 0.122963, "p_hi": 0.125942}
# {"ts_ns": 1770855196928767819, "event": "SLICE_METRIC", "z": 157, "fusion_score": 0.0, "local_std": 0.111307, "adaptive_weight": 0.12, "p_lo": 0.12299, "p_hi": 0.126354}
# {"ts_ns": 1770855196933457724, "event": "SLICE_METRIC", "z": 158, "fusion_score": 0.0, "local_std": 0.112843, "adaptive_weight": 0.12, "p_lo": 0.12304, "p_hi": 0.126333}
# {"ts_ns": 1770855196938193055, "event": "SLICE_METRIC", "z": 159, "fusion_score": 0.0, "local_std": 0.113929, "adaptive_weight": 0.12, "p_lo": 0.123088, "p_hi": 0.126544}
# {"ts_ns": 1770855196943157327, "event": "SLICE_METRIC", "z": 160, "fusion_score": 0.0, "local_std": 0.114775, "adaptive_weight": 0.12, "p_lo": 0.123136, "p_hi": 0.126563}
# {"ts_ns": 1770855196947528984, "event": "SLICE_METRIC", "z": 161, "fusion_score": 0.0, "local_std": 0.115477, "adaptive_weight": 0.12, "p_lo": 0.12321, "p_hi": 0.126976}
# {"ts_ns": 1770855196952230633, "event": "SLICE_METRIC", "z": 162, "fusion_score": 0.0, "local_std": 0.115911, "adaptive_weight": 0.12, "p_lo": 0.123198, "p_hi": 0.126978}
# {"ts_ns": 1770855196956809486, "event": "SLICE_METRIC", "z": 163, "fusion_score": 0.0, "local_std": 0.116376, "adaptive_weight": 0.12, "p_lo": 0.123263, "p_hi": 0.127125}
# {"ts_ns": 1770855196961325455, "event": "SLICE_METRIC", "z": 164, "fusion_score": 0.0, "local_std": 0.117301, "adaptive_weight": 0.12, "p_lo": 0.123277, "p_hi": 0.127027}
# {"ts_ns": 1770855196965992941, "event": "SLICE_METRIC", "z": 165, "fusion_score": 0.0, "local_std": 0.118298, "adaptive_weight": 0.12, "p_lo": 0.123326, "p_hi": 0.12711}
# {"ts_ns": 1770855196970760315, "event": "SLICE_METRIC", "z": 166, "fusion_score": 0.0, "local_std": 0.119168, "adaptive_weight": 0.12, "p_lo": 0.12343, "p_hi": 0.127534}
# {"ts_ns": 1770855196975365114, "event": "SLICE_METRIC", "z": 167, "fusion_score": 0.0, "local_std": 0.120018, "adaptive_weight": 0.12, "p_lo": 0.123486, "p_hi": 0.127847}
# {"ts_ns": 1770855196980605802, "event": "SLICE_METRIC", "z": 168, "fusion_score": 0.0, "local_std": 0.120594, "adaptive_weight": 0.12, "p_lo": 0.123438, "p_hi": 0.127805}
# {"ts_ns": 1770855196986112676, "event": "SLICE_METRIC", "z": 169, "fusion_score": 0.0, "local_std": 0.120485, "adaptive_weight": 0.12, "p_lo": 0.123441, "p_hi": 0.127685}
# {"ts_ns": 1770855196991019221, "event": "SLICE_METRIC", "z": 170, "fusion_score": 0.0, "local_std": 0.120171, "adaptive_weight": 0.12, "p_lo": 0.12346, "p_hi": 0.127727}
# {"ts_ns": 1770855196995629550, "event": "SLICE_METRIC", "z": 171, "fusion_score": 0.0, "local_std": 0.119955, "adaptive_weight": 0.12, "p_lo": 0.123403, "p_hi": 0.127589}
# {"ts_ns": 1770855197000469565, "event": "SLICE_METRIC", "z": 172, "fusion_score": 0.0, "local_std": 0.119803, "adaptive_weight": 0.12, "p_lo": 0.123421, "p_hi": 0.127588}
# {"ts_ns": 1770855197005010032, "event": "SLICE_METRIC", "z": 173, "fusion_score": 0.0, "local_std": 0.120161, "adaptive_weight": 0.12, "p_lo": 0.123419, "p_hi": 0.127742}
# {"ts_ns": 1770855197010153221, "event": "SLICE_METRIC", "z": 174, "fusion_score": 0.0, "local_std": 0.121019, "adaptive_weight": 0.12, "p_lo": 0.123466, "p_hi": 0.127851}
# {"ts_ns": 1770855197015189172, "event": "SLICE_METRIC", "z": 175, "fusion_score": 0.0, "local_std": 0.122059, "adaptive_weight": 0.12, "p_lo": 0.123484, "p_hi": 0.12802}
# {"ts_ns": 1770855197019875571, "event": "SLICE_METRIC", "z": 176, "fusion_score": 0.0, "local_std": 0.123302, "adaptive_weight": 0.12, "p_lo": 0.1236, "p_hi": 0.128212}
# {"ts_ns": 1770855197024692181, "event": "SLICE_METRIC", "z": 177, "fusion_score": 0.0, "local_std": 0.124269, "adaptive_weight": 0.12, "p_lo": 0.123766, "p_hi": 0.128586}
# {"ts_ns": 1770855197029574209, "event": "SLICE_METRIC", "z": 178, "fusion_score": 0.0, "local_std": 0.124921, "adaptive_weight": 0.12, "p_lo": 0.1239, "p_hi": 0.128817}
# {"ts_ns": 1770855197033784475, "event": "SLICE_METRIC", "z": 179, "fusion_score": 0.0, "local_std": 0.125062, "adaptive_weight": 0.12, "p_lo": 0.123785, "p_hi": 0.128738}
# {"ts_ns": 1770855197038583965, "event": "SLICE_METRIC", "z": 180, "fusion_score": 0.0, "local_std": 0.125127, "adaptive_weight": 0.12, "p_lo": 0.123736, "p_hi": 0.128417}
# {"ts_ns": 1770855197043468311, "event": "SLICE_METRIC", "z": 181, "fusion_score": 0.0, "local_std": 0.124691, "adaptive_weight": 0.12, "p_lo": 0.123668, "p_hi": 0.128515}
# {"ts_ns": 1770855197047827482, "event": "SLICE_METRIC", "z": 182, "fusion_score": 0.0, "local_std": 0.124395, "adaptive_weight": 0.12, "p_lo": 0.123655, "p_hi": 0.128499}
# {"ts_ns": 1770855197052309605, "event": "SLICE_METRIC", "z": 183, "fusion_score": 0.0, "local_std": 0.124096, "adaptive_weight": 0.12, "p_lo": 0.123644, "p_hi": 0.128421}
# {"ts_ns": 1770855197056531114, "event": "SLICE_METRIC", "z": 184, "fusion_score": 0.0, "local_std": 0.123892, "adaptive_weight": 0.12, "p_lo": 0.123579, "p_hi": 0.128265}
# {"ts_ns": 1770855197061153458, "event": "SLICE_METRIC", "z": 185, "fusion_score": 0.0, "local_std": 0.123419, "adaptive_weight": 0.12, "p_lo": 0.123533, "p_hi": 0.128245}
# {"ts_ns": 1770855197066008732, "event": "SLICE_METRIC", "z": 186, "fusion_score": 0.0, "local_std": 0.12319, "adaptive_weight": 0.12, "p_lo": 0.123573, "p_hi": 0.128225}
# {"ts_ns": 1770855197070796339, "event": "SLICE_METRIC", "z": 187, "fusion_score": 0.0, "local_std": 0.122902, "adaptive_weight": 0.12, "p_lo": 0.123604, "p_hi": 0.12812}
# {"ts_ns": 1770855197076023352, "event": "SLICE_METRIC", "z": 188, "fusion_score": 0.0, "local_std": 0.122754, "adaptive_weight": 0.12, "p_lo": 0.123612, "p_hi": 0.12812}
# {"ts_ns": 1770855197080640575, "event": "SLICE_METRIC", "z": 189, "fusion_score": 0.0, "local_std": 0.123011, "adaptive_weight": 0.12, "p_lo": 0.123589, "p_hi": 0.128013}
# {"ts_ns": 1770855197085230729, "event": "SLICE_METRIC", "z": 190, "fusion_score": 0.0, "local_std": 0.123147, "adaptive_weight": 0.12, "p_lo": 0.123589, "p_hi": 0.128212}
# {"ts_ns": 1770855197089528769, "event": "SLICE_METRIC", "z": 191, "fusion_score": 0.0, "local_std": 0.123022, "adaptive_weight": 0.12, "p_lo": 0.123575, "p_hi": 0.128558}
# {"ts_ns": 1770855197095292422, "event": "SLICE_METRIC", "z": 192, "fusion_score": 0.0, "local_std": 0.122842, "adaptive_weight": 0.12, "p_lo": 0.123662, "p_hi": 0.128547}
# {"ts_ns": 1770855197100107834, "event": "SLICE_METRIC", "z": 193, "fusion_score": 0.0, "local_std": 0.12287, "adaptive_weight": 0.12, "p_lo": 0.123553, "p_hi": 0.128154}
# {"ts_ns": 1770855197104802444, "event": "SLICE_METRIC", "z": 194, "fusion_score": 0.0, "local_std": 0.122894, "adaptive_weight": 0.12, "p_lo": 0.123586, "p_hi": 0.128205}
# {"ts_ns": 1770855197109361551, "event": "SLICE_METRIC", "z": 195, "fusion_score": 0.0, "local_std": 0.123103, "adaptive_weight": 0.12, "p_lo": 0.123687, "p_hi": 0.12832}
# {"ts_ns": 1770855197113749982, "event": "SLICE_METRIC", "z": 196, "fusion_score": 0.0, "local_std": 0.123582, "adaptive_weight": 0.12, "p_lo": 0.123739, "p_hi": 0.128609}
# {"ts_ns": 1770855197118730970, "event": "SLICE_METRIC", "z": 197, "fusion_score": 0.0, "local_std": 0.124339, "adaptive_weight": 0.12, "p_lo": 0.123708, "p_hi": 0.128505}
# {"ts_ns": 1770855197123658632, "event": "SLICE_METRIC", "z": 198, "fusion_score": 0.0, "local_std": 0.124813, "adaptive_weight": 0.12, "p_lo": 0.123708, "p_hi": 0.128497}
# {"ts_ns": 1770855197128256142, "event": "SLICE_METRIC", "z": 199, "fusion_score": 0.0, "local_std": 0.125144, "adaptive_weight": 0.12, "p_lo": 0.123746, "p_hi": 0.128743}
# {"ts_ns": 1770855197133270516, "event": "SLICE_METRIC", "z": 200, "fusion_score": 0.0, "local_std": 0.125326, "adaptive_weight": 0.12, "p_lo": 0.123704, "p_hi": 0.128743}
# {"ts_ns": 1770855197137500995, "event": "SLICE_METRIC", "z": 201, "fusion_score": 0.0, "local_std": 0.125431, "adaptive_weight": 0.12, "p_lo": 0.123735, "p_hi": 0.128633}
# {"ts_ns": 1770855197141874705, "event": "SLICE_METRIC", "z": 202, "fusion_score": 0.0, "local_std": 0.125219, "adaptive_weight": 0.12, "p_lo": 0.12365, "p_hi": 0.12861}
# {"ts_ns": 1770855197146667477, "event": "SLICE_METRIC", "z": 203, "fusion_score": 0.0, "local_std": 0.124955, "adaptive_weight": 0.12, "p_lo": 0.123689, "p_hi": 0.128549}
# {"ts_ns": 1770855197151193385, "event": "SLICE_METRIC", "z": 204, "fusion_score": 0.0, "local_std": 0.124497, "adaptive_weight": 0.12, "p_lo": 0.123681, "p_hi": 0.128433}
# {"ts_ns": 1770855197155609422, "event": "SLICE_METRIC", "z": 205, "fusion_score": 0.0, "local_std": 0.124433, "adaptive_weight": 0.12, "p_lo": 0.123677, "p_hi": 0.128467}
# {"ts_ns": 1770855197160102872, "event": "SLICE_METRIC", "z": 206, "fusion_score": 0.0, "local_std": 0.124655, "adaptive_weight": 0.12, "p_lo": 0.123609, "p_hi": 0.128541}
# {"ts_ns": 1770855197164805170, "event": "SLICE_METRIC", "z": 207, "fusion_score": 0.0, "local_std": 0.125283, "adaptive_weight": 0.12, "p_lo": 0.123714, "p_hi": 0.128483}
# {"ts_ns": 1770855197170164025, "event": "SLICE_METRIC", "z": 208, "fusion_score": 0.0, "local_std": 0.125905, "adaptive_weight": 0.12, "p_lo": 0.123711, "p_hi": 0.128642}
# {"ts_ns": 1770855197174706157, "event": "SLICE_METRIC", "z": 209, "fusion_score": 0.0, "local_std": 0.126651, "adaptive_weight": 0.12, "p_lo": 0.123878, "p_hi": 0.128944}
# {"ts_ns": 1770855197179351256, "event": "SLICE_METRIC", "z": 210, "fusion_score": 0.0, "local_std": 0.126895, "adaptive_weight": 0.12, "p_lo": 0.123866, "p_hi": 0.129115}
# {"ts_ns": 1770855197184178752, "event": "SLICE_METRIC", "z": 211, "fusion_score": 0.0, "local_std": 0.126835, "adaptive_weight": 0.12, "p_lo": 0.123744, "p_hi": 0.128951}
# {"ts_ns": 1770855197189589927, "event": "SLICE_METRIC", "z": 212, "fusion_score": 0.0, "local_std": 0.126286, "adaptive_weight": 0.12, "p_lo": 0.123649, "p_hi": 0.128838}
# {"ts_ns": 1770855197194192732, "event": "SLICE_METRIC", "z": 213, "fusion_score": 0.0, "local_std": 0.125818, "adaptive_weight": 0.12, "p_lo": 0.123681, "p_hi": 0.128788}
# {"ts_ns": 1770855197199326152, "event": "SLICE_METRIC", "z": 214, "fusion_score": 0.0, "local_std": 0.12519, "adaptive_weight": 0.12, "p_lo": 0.123676, "p_hi": 0.128873}
# {"ts_ns": 1770855197204166618, "event": "SLICE_METRIC", "z": 215, "fusion_score": 0.0, "local_std": 0.124805, "adaptive_weight": 0.12, "p_lo": 0.123646, "p_hi": 0.128619}
# {"ts_ns": 1770855197208861556, "event": "SLICE_METRIC", "z": 216, "fusion_score": 0.0, "local_std": 0.124269, "adaptive_weight": 0.12, "p_lo": 0.123631, "p_hi": 0.128653}
# {"ts_ns": 1770855197214136752, "event": "SLICE_METRIC", "z": 217, "fusion_score": 0.0, "local_std": 0.123817, "adaptive_weight": 0.12, "p_lo": 0.123589, "p_hi": 0.128528}
# {"ts_ns": 1770855197218631427, "event": "SLICE_METRIC", "z": 218, "fusion_score": 0.0, "local_std": 0.123077, "adaptive_weight": 0.12, "p_lo": 0.123504, "p_hi": 0.128305}
# {"ts_ns": 1770855197223265649, "event": "SLICE_METRIC", "z": 219, "fusion_score": 0.0, "local_std": 0.122467, "adaptive_weight": 0.12, "p_lo": 0.123515, "p_hi": 0.128449}
# {"ts_ns": 1770855197227967173, "event": "SLICE_METRIC", "z": 220, "fusion_score": 0.0, "local_std": 0.121699, "adaptive_weight": 0.12, "p_lo": 0.123461, "p_hi": 0.128469}
# {"ts_ns": 1770855197232313632, "event": "SLICE_METRIC", "z": 221, "fusion_score": 0.0, "local_std": 0.121534, "adaptive_weight": 0.12, "p_lo": 0.123401, "p_hi": 0.128233}
# {"ts_ns": 1770855197236873232, "event": "SLICE_METRIC", "z": 222, "fusion_score": 0.0, "local_std": 0.121781, "adaptive_weight": 0.12, "p_lo": 0.123365, "p_hi": 0.1283}
# {"ts_ns": 1770855197241239922, "event": "SLICE_METRIC", "z": 223, "fusion_score": 0.0, "local_std": 0.121867, "adaptive_weight": 0.12, "p_lo": 0.123437, "p_hi": 0.128279}
# {"ts_ns": 1770855197246308367, "event": "SLICE_METRIC", "z": 224, "fusion_score": 0.0, "local_std": 0.121596, "adaptive_weight": 0.12, "p_lo": 0.123484, "p_hi": 0.128583}
# {"ts_ns": 1770855197251136345, "event": "SLICE_METRIC", "z": 225, "fusion_score": 0.0, "local_std": 0.121337, "adaptive_weight": 0.12, "p_lo": 0.123299, "p_hi": 0.128177}
# {"ts_ns": 1770855197255750727, "event": "SLICE_METRIC", "z": 226, "fusion_score": 0.0, "local_std": 0.120653, "adaptive_weight": 0.12, "p_lo": 0.123249, "p_hi": 0.127801}
# {"ts_ns": 1770855197259846172, "event": "SLICE_METRIC", "z": 227, "fusion_score": 0.0, "local_std": 0.119601, "adaptive_weight": 0.12, "p_lo": 0.123228, "p_hi": 0.127797}
# {"ts_ns": 1770855197264603859, "event": "SLICE_METRIC", "z": 228, "fusion_score": 0.0, "local_std": 0.119001, "adaptive_weight": 0.12, "p_lo": 0.123332, "p_hi": 0.127913}
# {"ts_ns": 1770855197269093607, "event": "SLICE_METRIC", "z": 229, "fusion_score": 0.0, "local_std": 0.118781, "adaptive_weight": 0.12, "p_lo": 0.12331, "p_hi": 0.127948}
# {"ts_ns": 1770855197273433487, "event": "SLICE_METRIC", "z": 230, "fusion_score": 0.0, "local_std": 0.118357, "adaptive_weight": 0.12, "p_lo": 0.123307, "p_hi": 0.127886}
# {"ts_ns": 1770855197278169013, "event": "SLICE_METRIC", "z": 231, "fusion_score": 0.0, "local_std": 0.118088, "adaptive_weight": 0.12, "p_lo": 0.123178, "p_hi": 0.127562}
# {"ts_ns": 1770855197282481383, "event": "SLICE_METRIC", "z": 232, "fusion_score": 0.0, "local_std": 0.118249, "adaptive_weight": 0.12, "p_lo": 0.123086, "p_hi": 0.127385}
# {"ts_ns": 1770855197287251530, "event": "SLICE_METRIC", "z": 233, "fusion_score": 0.0, "local_std": 0.118382, "adaptive_weight": 0.12, "p_lo": 0.123152, "p_hi": 0.127469}
# {"ts_ns": 1770855197291528156, "event": "SLICE_METRIC", "z": 234, "fusion_score": 0.0, "local_std": 0.118446, "adaptive_weight": 0.12, "p_lo": 0.123229, "p_hi": 0.127703}
# {"ts_ns": 1770855197296131426, "event": "SLICE_METRIC", "z": 235, "fusion_score": 0.0, "local_std": 0.118944, "adaptive_weight": 0.12, "p_lo": 0.123305, "p_hi": 0.127684}
# {"ts_ns": 1770855197300570109, "event": "SLICE_METRIC", "z": 236, "fusion_score": 0.0, "local_std": 0.119121, "adaptive_weight": 0.12, "p_lo": 0.123222, "p_hi": 0.127541}
# {"ts_ns": 1770855197305564885, "event": "SLICE_METRIC", "z": 237, "fusion_score": 0.0, "local_std": 0.118769, "adaptive_weight": 0.12, "p_lo": 0.123253, "p_hi": 0.127459}
# {"ts_ns": 1770855197310029805, "event": "SLICE_METRIC", "z": 238, "fusion_score": 0.0, "local_std": 0.118202, "adaptive_weight": 0.12, "p_lo": 0.123251, "p_hi": 0.127528}
# {"ts_ns": 1770855197314225721, "event": "SLICE_METRIC", "z": 239, "fusion_score": 0.0, "local_std": 0.117453, "adaptive_weight": 0.12, "p_lo": 0.123142, "p_hi": 0.127346}
# {"ts_ns": 1770855197319217356, "event": "SLICE_METRIC", "z": 240, "fusion_score": 0.0, "local_std": 0.116711, "adaptive_weight": 0.12, "p_lo": 0.123121, "p_hi": 0.127251}
# {"ts_ns": 1770855197323762796, "event": "SLICE_METRIC", "z": 241, "fusion_score": 0.0, "local_std": 0.116014, "adaptive_weight": 0.12, "p_lo": 0.123082, "p_hi": 0.127251}
# {"ts_ns": 1770855197328198113, "event": "SLICE_METRIC", "z": 242, "fusion_score": 0.0, "local_std": 0.115375, "adaptive_weight": 0.12, "p_lo": 0.123055, "p_hi": 0.127139}
# {"ts_ns": 1770855197333263248, "event": "SLICE_METRIC", "z": 243, "fusion_score": 0.0, "local_std": 0.114709, "adaptive_weight": 0.12, "p_lo": 0.123054, "p_hi": 0.127371}
# {"ts_ns": 1770855197337514414, "event": "SLICE_METRIC", "z": 244, "fusion_score": 0.0, "local_std": 0.11424, "adaptive_weight": 0.12, "p_lo": 0.123066, "p_hi": 0.127173}
# {"ts_ns": 1770855197342278000, "event": "SLICE_METRIC", "z": 245, "fusion_score": 0.0, "local_std": 0.113673, "adaptive_weight": 0.12, "p_lo": 0.123028, "p_hi": 0.126987}
# {"ts_ns": 1770855197346554429, "event": "SLICE_METRIC", "z": 246, "fusion_score": 0.0, "local_std": 0.113113, "adaptive_weight": 0.12, "p_lo": 0.122981, "p_hi": 0.126888}
# {"ts_ns": 1770855197351163623, "event": "SLICE_METRIC", "z": 247, "fusion_score": 0.0, "local_std": 0.112896, "adaptive_weight": 0.12, "p_lo": 0.122966, "p_hi": 0.127011}
# {"ts_ns": 1770855197356120767, "event": "SLICE_METRIC", "z": 248, "fusion_score": 0.0, "local_std": 0.112892, "adaptive_weight": 0.12, "p_lo": 0.122973, "p_hi": 0.126948}
# {"ts_ns": 1770855197360551128, "event": "SLICE_METRIC", "z": 249, "fusion_score": 0.0, "local_std": 0.112583, "adaptive_weight": 0.12, "p_lo": 0.122994, "p_hi": 0.127039}
# {"ts_ns": 1770855197365500324, "event": "SLICE_METRIC", "z": 250, "fusion_score": 0.0, "local_std": 0.111918, "adaptive_weight": 0.12, "p_lo": 0.123053, "p_hi": 0.127054}
# {"ts_ns": 1770855197370332995, "event": "SLICE_METRIC", "z": 251, "fusion_score": 0.0, "local_std": 0.111214, "adaptive_weight": 0.12, "p_lo": 0.123001, "p_hi": 0.126999}
# {"ts_ns": 1770855197375284262, "event": "SLICE_METRIC", "z": 252, "fusion_score": 0.0, "local_std": 0.11077, "adaptive_weight": 0.12, "p_lo": 0.12293, "p_hi": 0.126594}
# {"ts_ns": 1770855197379693895, "event": "SLICE_METRIC", "z": 253, "fusion_score": 0.0, "local_std": 0.110511, "adaptive_weight": 0.12, "p_lo": 0.122906, "p_hi": 0.126564}
# {"ts_ns": 1770855197384432463, "event": "SLICE_METRIC", "z": 254, "fusion_score": 0.0, "local_std": 0.11064, "adaptive_weight": 0.12, "p_lo": 0.12294, "p_hi": 0.1268}
# {"ts_ns": 1770855197390149335, "event": "SLICE_METRIC", "z": 255, "fusion_score": 0.0, "local_std": 0.11116, "adaptive_weight": 0.12, "p_lo": 0.123013, "p_hi": 0.12705}
# {"ts_ns": 1770855197395670657, "event": "SLICE_METRIC", "z": 256, "fusion_score": 0.0, "local_std": 0.111792, "adaptive_weight": 0.12, "p_lo": 0.122961, "p_hi": 0.126977}
# {"ts_ns": 1770855197400819031, "event": "SLICE_METRIC", "z": 257, "fusion_score": 0.0, "local_std": 0.11181, "adaptive_weight": 0.12, "p_lo": 0.122962, "p_hi": 0.127032}
# {"ts_ns": 1770855197405452435, "event": "SLICE_METRIC", "z": 258, "fusion_score": 0.0, "local_std": 0.111606, "adaptive_weight": 0.12, "p_lo": 0.122939, "p_hi": 0.126951}
# {"ts_ns": 1770855197410297587, "event": "SLICE_METRIC", "z": 259, "fusion_score": 0.0, "local_std": 0.111249, "adaptive_weight": 0.12, "p_lo": 0.12297, "p_hi": 0.126856}
# {"ts_ns": 1770855197415212594, "event": "SLICE_METRIC", "z": 260, "fusion_score": 0.0, "local_std": 0.11091, "adaptive_weight": 0.12, "p_lo": 0.122884, "p_hi": 0.126719}
# {"ts_ns": 1770855197419637030, "event": "SLICE_METRIC", "z": 261, "fusion_score": 0.0, "local_std": 0.110658, "adaptive_weight": 0.12, "p_lo": 0.122916, "p_hi": 0.126816}
# {"ts_ns": 1770855197424046239, "event": "SLICE_METRIC", "z": 262, "fusion_score": 0.0, "local_std": 0.110816, "adaptive_weight": 0.12, "p_lo": 0.12295, "p_hi": 0.126569}
# {"ts_ns": 1770855197428912585, "event": "SLICE_METRIC", "z": 263, "fusion_score": 0.0, "local_std": 0.111088, "adaptive_weight": 0.12, "p_lo": 0.122953, "p_hi": 0.126802}
# {"ts_ns": 1770855197433902225, "event": "SLICE_METRIC", "z": 264, "fusion_score": 0.0, "local_std": 0.111408, "adaptive_weight": 0.12, "p_lo": 0.122997, "p_hi": 0.126727}
# {"ts_ns": 1770855197438790528, "event": "SLICE_METRIC", "z": 265, "fusion_score": 0.0, "local_std": 0.111573, "adaptive_weight": 0.12, "p_lo": 0.122972, "p_hi": 0.126901}
# {"ts_ns": 1770855197443599799, "event": "SLICE_METRIC", "z": 266, "fusion_score": 0.0, "local_std": 0.11146, "adaptive_weight": 0.12, "p_lo": 0.123003, "p_hi": 0.126834}
# {"ts_ns": 1770855197448234528, "event": "SLICE_METRIC", "z": 267, "fusion_score": 0.0, "local_std": 0.111248, "adaptive_weight": 0.12, "p_lo": 0.12295, "p_hi": 0.126475}
# {"ts_ns": 1770855197453000574, "event": "SLICE_METRIC", "z": 268, "fusion_score": 0.0, "local_std": 0.111164, "adaptive_weight": 0.12, "p_lo": 0.122977, "p_hi": 0.126451}
# {"ts_ns": 1770855197457737774, "event": "SLICE_METRIC", "z": 269, "fusion_score": 0.0, "local_std": 0.111549, "adaptive_weight": 0.12, "p_lo": 0.122895, "p_hi": 0.126275}
# {"ts_ns": 1770855197462179003, "event": "SLICE_METRIC", "z": 270, "fusion_score": 0.0, "local_std": 0.112188, "adaptive_weight": 0.12, "p_lo": 0.122955, "p_hi": 0.126515}
# {"ts_ns": 1770855197466868590, "event": "SLICE_METRIC", "z": 271, "fusion_score": 0.0, "local_std": 0.113041, "adaptive_weight": 0.12, "p_lo": 0.122969, "p_hi": 0.126702}
# {"ts_ns": 1770855197472097768, "event": "SLICE_METRIC", "z": 272, "fusion_score": 0.0, "local_std": 0.114078, "adaptive_weight": 0.12, "p_lo": 0.123014, "p_hi": 0.126677}
# {"ts_ns": 1770855197476362139, "event": "SLICE_METRIC", "z": 273, "fusion_score": 0.0, "local_std": 0.114884, "adaptive_weight": 0.12, "p_lo": 0.122995, "p_hi": 0.126714}
# {"ts_ns": 1770855197481067866, "event": "SLICE_METRIC", "z": 274, "fusion_score": 0.0, "local_std": 0.115204, "adaptive_weight": 0.12, "p_lo": 0.123038, "p_hi": 0.126814}
# {"ts_ns": 1770855197485779749, "event": "SLICE_METRIC", "z": 275, "fusion_score": 0.0, "local_std": 0.115348, "adaptive_weight": 0.12, "p_lo": 0.123052, "p_hi": 0.127166}
# {"ts_ns": 1770855197490394928, "event": "SLICE_METRIC", "z": 276, "fusion_score": 0.0, "local_std": 0.115527, "adaptive_weight": 0.12, "p_lo": 0.123057, "p_hi": 0.127014}
# {"ts_ns": 1770855197495496565, "event": "SLICE_METRIC", "z": 277, "fusion_score": 0.0, "local_std": 0.115373, "adaptive_weight": 0.12, "p_lo": 0.123132, "p_hi": 0.127163}
# {"ts_ns": 1770855197500302635, "event": "SLICE_METRIC", "z": 278, "fusion_score": 0.0, "local_std": 0.115279, "adaptive_weight": 0.12, "p_lo": 0.123172, "p_hi": 0.127399}
# {"ts_ns": 1770855197504663024, "event": "SLICE_METRIC", "z": 279, "fusion_score": 0.0, "local_std": 0.115263, "adaptive_weight": 0.12, "p_lo": 0.123119, "p_hi": 0.127334}
# {"ts_ns": 1770855197509289200, "event": "SLICE_METRIC", "z": 280, "fusion_score": 0.0, "local_std": 0.115518, "adaptive_weight": 0.12, "p_lo": 0.123118, "p_hi": 0.127308}
# {"ts_ns": 1770855197513689915, "event": "SLICE_METRIC", "z": 281, "fusion_score": 0.0, "local_std": 0.11593, "adaptive_weight": 0.12, "p_lo": 0.123108, "p_hi": 0.127427}
# {"ts_ns": 1770855197518086054, "event": "SLICE_METRIC", "z": 282, "fusion_score": 0.0, "local_std": 0.116356, "adaptive_weight": 0.12, "p_lo": 0.123198, "p_hi": 0.127376}
# {"ts_ns": 1770855197522815270, "event": "SLICE_METRIC", "z": 283, "fusion_score": 0.0, "local_std": 0.116681, "adaptive_weight": 0.12, "p_lo": 0.12332, "p_hi": 0.12755}
# {"ts_ns": 1770855197527269570, "event": "SLICE_METRIC", "z": 284, "fusion_score": 0.0, "local_std": 0.117052, "adaptive_weight": 0.12, "p_lo": 0.123318, "p_hi": 0.127898}
# {"ts_ns": 1770855197532290713, "event": "SLICE_METRIC", "z": 285, "fusion_score": 0.0, "local_std": 0.117068, "adaptive_weight": 0.12, "p_lo": 0.123231, "p_hi": 0.127866}
# {"ts_ns": 1770855197537264671, "event": "SLICE_METRIC", "z": 286, "fusion_score": 0.0, "local_std": 0.117066, "adaptive_weight": 0.12, "p_lo": 0.123242, "p_hi": 0.127804}
# {"ts_ns": 1770855197542041306, "event": "SLICE_METRIC", "z": 287, "fusion_score": 0.0, "local_std": 0.117167, "adaptive_weight": 0.12, "p_lo": 0.123207, "p_hi": 0.127697}
# {"ts_ns": 1770855197547105437, "event": "SLICE_METRIC", "z": 288, "fusion_score": 0.0, "local_std": 0.117089, "adaptive_weight": 0.12, "p_lo": 0.123263, "p_hi": 0.127838}
# {"ts_ns": 1770855197551736079, "event": "SLICE_METRIC", "z": 289, "fusion_score": 0.0, "local_std": 0.116971, "adaptive_weight": 0.12, "p_lo": 0.123207, "p_hi": 0.127649}
# {"ts_ns": 1770855197556205704, "event": "SLICE_METRIC", "z": 290, "fusion_score": 0.0, "local_std": 0.116862, "adaptive_weight": 0.12, "p_lo": 0.123174, "p_hi": 0.127439}
# {"ts_ns": 1770855197560657279, "event": "SLICE_METRIC", "z": 291, "fusion_score": 0.0, "local_std": 0.116563, "adaptive_weight": 0.12, "p_lo": 0.123193, "p_hi": 0.127399}
# {"ts_ns": 1770855197565270095, "event": "SLICE_METRIC", "z": 292, "fusion_score": 0.0, "local_std": 0.116208, "adaptive_weight": 0.12, "p_lo": 0.123128, "p_hi": 0.127487}
# {"ts_ns": 1770855197569947210, "event": "SLICE_METRIC", "z": 293, "fusion_score": 0.0, "local_std": 0.11575, "adaptive_weight": 0.12, "p_lo": 0.12313, "p_hi": 0.127241}
# {"ts_ns": 1770855197574654049, "event": "SLICE_METRIC", "z": 294, "fusion_score": 0.0, "local_std": 0.115111, "adaptive_weight": 0.12, "p_lo": 0.123149, "p_hi": 0.127269}
# {"ts_ns": 1770855197579324111, "event": "SLICE_METRIC", "z": 295, "fusion_score": 0.0, "local_std": 0.114711, "adaptive_weight": 0.12, "p_lo": 0.12309, "p_hi": 0.12714}
# {"ts_ns": 1770855197583785578, "event": "SLICE_METRIC", "z": 296, "fusion_score": 0.0, "local_std": 0.114394, "adaptive_weight": 0.12, "p_lo": 0.123038, "p_hi": 0.127001}
# {"ts_ns": 1770855197588723545, "event": "SLICE_METRIC", "z": 297, "fusion_score": 0.0, "local_std": 0.114088, "adaptive_weight": 0.12, "p_lo": 0.123013, "p_hi": 0.127074}
# {"ts_ns": 1770855197594270935, "event": "SLICE_METRIC", "z": 298, "fusion_score": 0.0, "local_std": 0.114059, "adaptive_weight": 0.12, "p_lo": 0.122976, "p_hi": 0.127192}
# {"ts_ns": 1770855197599855167, "event": "SLICE_METRIC", "z": 299, "fusion_score": 0.0, "local_std": 0.113892, "adaptive_weight": 0.12, "p_lo": 0.122987, "p_hi": 0.127193}
# {"ts_ns": 1770855197604504785, "event": "SLICE_METRIC", "z": 300, "fusion_score": 0.0, "local_std": 0.113622, "adaptive_weight": 0.12, "p_lo": 0.122986, "p_hi": 0.127191}
# {"ts_ns": 1770855197609523049, "event": "SLICE_METRIC", "z": 301, "fusion_score": 0.0, "local_std": 0.11317, "adaptive_weight": 0.12, "p_lo": 0.122975, "p_hi": 0.12715}
# {"ts_ns": 1770855197615307150, "event": "SLICE_METRIC", "z": 302, "fusion_score": 0.0, "local_std": 0.112615, "adaptive_weight": 0.12, "p_lo": 0.123008, "p_hi": 0.126945}
# {"ts_ns": 1770855197620261806, "event": "SLICE_METRIC", "z": 303, "fusion_score": 0.0, "local_std": 0.112011, "adaptive_weight": 0.12, "p_lo": 0.122969, "p_hi": 0.126877}
# {"ts_ns": 1770855197625634388, "event": "SLICE_METRIC", "z": 304, "fusion_score": 0.0, "local_std": 0.111665, "adaptive_weight": 0.12, "p_lo": 0.122986, "p_hi": 0.12701}
# {"ts_ns": 1770855197630419790, "event": "SLICE_METRIC", "z": 305, "fusion_score": 0.0, "local_std": 0.110939, "adaptive_weight": 0.12, "p_lo": 0.122976, "p_hi": 0.126835}
# {"ts_ns": 1770855197634661037, "event": "SLICE_METRIC", "z": 306, "fusion_score": 0.0, "local_std": 0.110096, "adaptive_weight": 0.12, "p_lo": 0.12295, "p_hi": 0.126697}
# {"ts_ns": 1770855197639386429, "event": "SLICE_METRIC", "z": 307, "fusion_score": 0.0, "local_std": 0.109329, "adaptive_weight": 0.12, "p_lo": 0.122944, "p_hi": 0.126543}
# {"ts_ns": 1770855197644143705, "event": "SLICE_METRIC", "z": 308, "fusion_score": 0.0, "local_std": 0.108775, "adaptive_weight": 0.12, "p_lo": 0.122948, "p_hi": 0.126422}
# {"ts_ns": 1770855197649015440, "event": "SLICE_METRIC", "z": 309, "fusion_score": 0.0, "local_std": 0.108315, "adaptive_weight": 0.12, "p_lo": 0.122943, "p_hi": 0.126463}
# {"ts_ns": 1770855197653551091, "event": "SLICE_METRIC", "z": 310, "fusion_score": 0.0, "local_std": 0.108124, "adaptive_weight": 0.12, "p_lo": 0.122831, "p_hi": 0.126447}
# {"ts_ns": 1770855197657973641, "event": "SLICE_METRIC", "z": 311, "fusion_score": 0.0, "local_std": 0.108254, "adaptive_weight": 0.12, "p_lo": 0.122829, "p_hi": 0.126237}
# {"ts_ns": 1770855197662761824, "event": "SLICE_METRIC", "z": 312, "fusion_score": 0.0, "local_std": 0.108392, "adaptive_weight": 0.12, "p_lo": 0.122782, "p_hi": 0.126217}
# {"ts_ns": 1770855197667715055, "event": "SLICE_METRIC", "z": 313, "fusion_score": 0.0, "local_std": 0.108258, "adaptive_weight": 0.12, "p_lo": 0.12285, "p_hi": 0.126233}
# {"ts_ns": 1770855197672301147, "event": "SLICE_METRIC", "z": 314, "fusion_score": 0.0, "local_std": 0.107869, "adaptive_weight": 0.12, "p_lo": 0.122801, "p_hi": 0.126382}
# {"ts_ns": 1770855197676862722, "event": "SLICE_METRIC", "z": 315, "fusion_score": 0.0, "local_std": 0.107758, "adaptive_weight": 0.12, "p_lo": 0.122872, "p_hi": 0.125952}
# {"ts_ns": 1770855197681293011, "event": "SLICE_METRIC", "z": 316, "fusion_score": 0.0, "local_std": 0.10763, "adaptive_weight": 0.12, "p_lo": 0.122892, "p_hi": 0.126048}
# {"ts_ns": 1770855197685936259, "event": "SLICE_METRIC", "z": 317, "fusion_score": 0.0, "local_std": 0.107645, "adaptive_weight": 0.12, "p_lo": 0.122825, "p_hi": 0.125801}
# {"ts_ns": 1770855197690531480, "event": "SLICE_METRIC", "z": 318, "fusion_score": 0.0, "local_std": 0.107583, "adaptive_weight": 0.12, "p_lo": 0.122394, "p_hi": 0.125184}
# {"ts_ns": 1770855197695339777, "event": "SLICE_METRIC", "z": 319, "fusion_score": 0.0, "local_std": 0.107903, "adaptive_weight": 0.12, "p_lo": 0.122879, "p_hi": 0.125923}
# {"ts_ns": 1770855218956690002, "event": "FILE_DONE", "file": "1407735.tif", "slices": 320}
# {"ts_ns": 1770855218961344289, "event": "EXEC_COMPLETE", "submission": "/kaggle/working/submission.zip"}
# READY: /kaggle/working/submission.zip
